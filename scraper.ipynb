# %%
import requests
from bs4 import BeautifulSoup
import csv
import re
import time
import json
import os

# %%
url_search = "https://dl.acm.org/action/doSearch?fillQuickSearch=false&target=advanced&expand=dl&AfterYear=2000&BeforeYear=2024&AllField=Title%3A%28%22Textile%22+OR+%22Fabric%22+AND+NOT+%22Network%22+AND+NOT+%22software+engineering%22+AND+NOT+%22decentralized%22%29+AND+Abstract%3A%28NOT+%22Network%22+AND+NOT+%22server%22+AND+NOT+%22render%22+AND+NOT+%22distributed%22+AND+NOT+%22software+engineering%22+AND+NOT+%22decentralized%22+AND+NOT+%22blockchain%22+AND+NOT+%22life+science%22%29&startPage=7&pageSize=50"

file_path = './data/papers_data.json'

# check if file exists
if os.path.exists(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        papers_data = json.load(file)
else:
    papers_data = []

res = requests.get(url_search)
soup = BeautifulSoup(res.text, "html.parser")
selector_paper = "div.issue-item.issue-item--search.clearfix"
papers = soup.select(selector_paper)

for paper in papers:
    # collapsed abstract
    abstract = paper.select("div.issue-item__abstract.truncate-text > p")
    abstract = [a.text for a in abstract]
    if len(abstract) > 0:
        abstract = abstract[0]
    else:
        # if no abstract, skip
        continue
    # title
    title = paper.select("h5 > span > a")
    title = [t.text for t in title]
    title = title[0]
    # authors
    authors = []
    author_tags = paper.select('ul[aria-label="authors"] > li > a')
    for tag in author_tags:
        authors.append(tag.text)
    # date
    date = paper.select("div.bookPubDate")
    date = [d.text for d in date]
    date = date[0]
    # year
    year = date.split(" ")[-1]
    # citations
    citations = paper.select("div.citation > span")
    citations = [c.text for c in citations]
    if len(citations) > 0:
        citations = int(citations[0].replace(",", ""))
    else:
        citations = 0
    # downloads
    downloads = paper.select("div.metric > span")
    downloads = [d.text for d in downloads]
    if len(downloads) > 0:
        downloads = int(downloads[0].replace(",", ""))
    else:
        downloads = 0
    # content type
    content_type = paper.select("div.issue-heading")
    content_type = [c.text for c in content_type]
    if len(content_type) > 0:
        content_type = content_type[0]
    else:
        content_type = ""
    # doi
    doi = paper.select("a.issue-item__doi")
    doi = [d.text for d in doi]
    if len(doi) > 0:
        doi = doi[0]
    else:
        continue
    # publication
    publication = paper.select("span.epub-section__title")
    publication = [p.text for p in publication]
    if len(publication) > 0:
        publication = publication[0].split(":")[0]
    else:
        continue

    new_paper = {
        "title": title,
        "abstract": abstract,
        "citation_num": citations,
        "download_num": downloads,
        "conference": publication, 
        "authors": authors,
        "contentType": content_type,
        "doi": doi,
        "date": date,
        "year": year
    }
    
    papers_data.append(new_paper)

# save to file
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(papers_data, file, indent=4)

# %%
def convert_doi_url(doi_url):
    # Split the original URL to get the DOI part
    doi_part = doi_url.split("https://doi.org/")[-1]
    
    # Construct the new URL using the ACM format
    new_url = f"https://dl.acm.org/doi/{doi_part}"
    
    return new_url

# %%
# get full abstract
file_path = './data/papers_data.json'
full_abstract_file_path = './data/papers_data_with_full_abstract.json'

if os.path.exists(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        papers_data = json.load(file)
    for paper in papers_data:
        print(convert_doi_url(paper["doi"]))
        res = requests.get(convert_doi_url(paper["doi"]))
        soup = BeautifulSoup(res.text, "html.parser")
        selector_full_abstract = "div.abstractSection.abstractInFull > p"
        full_abstract_elements = soup.select(selector_full_abstract)
        full_abstract_text = " ".join([element.text for element in full_abstract_elements])
        
        # update the paper data with the full abstract
        paper["abstract_full"] = full_abstract_text

        # check if file exists
        if not os.path.exists(full_abstract_file_path):
            existing_data = []
        else:
            with open(full_abstract_file_path, 'r', encoding='utf-8') as file:
                existing_data = json.load(file)
        
        # add the new paper to the existing data
        existing_data.append(paper)
        
        # write the updated data back to the file
        with open(full_abstract_file_path, 'w', encoding='utf-8') as file:
            json.dump(existing_data, file, indent=4)
        
        print(full_abstract_text)
        time.sleep(10)
# Out:
# https://dl.acm.org/doi/10.1145/3316782.3316785
# Back pain is one of the most common illnesses in Western civilizations. Office work and lack of motion can lead to deterioration over time. Many people already use seat cushions to improve their posture during work or leisure. In this work, we present an E-Textile cushion. This seat cushion is equipped with capacitive proximity sensors that track the proximity and motion of the sitting user and distinguish up to 7 postures. Giving a user immediate feedback on the posture can facilitate more healthy behavior. We evaluated a number of different electrode setups, materials, and classification methods, leading to a maximum accuracy of 97.1%.
# https://dl.acm.org/doi/10.1145/3123514.3123565
# The Aural Fabric is an interactive textile sonic map created to promote engagement in acoustic awareness towards the built environment. It fosters discussions on the aural environment of our cities by allowing users to experience binaural recordings captured during a soundwalk. The touch of the conductive areas embroidered of the surface on the map can be sensed by two capacitive boards stitched on the map. These are externally connected to an embedded computer processing unit, Bela. The recordings can be intuitively mixed together offering exploratory and performative recall of the material collected.
# https://dl.acm.org/doi/10.1145/3084863.3084868
# Here we introduce our system Textile++, a touch-sensitive cloth consisting of fiber materials. With this system, it is possible to detect the XY coordinate position of the substance touching the cloth. In addition, pressure can be detected. Textile++ is flexible and lightweight, making it is easy to apply to conventional clothes. Compared to existing methods, the structure is simple, so it is possible to manufacture at very low cost. This paper explains the proposed Textile ++ system and its application to a cuff-based user interface (UI) created for a jacket (Figure 1).
# https://dl.acm.org/doi/10.1145/2556288.2557299
# Group exercise has multiple benefits including greater adherence to fitness regimens, increased enjoyment among participants, and enhanced workout intensity. While a large number of technology tools have emerged to support real-time feedback of individual performance, tools to support group fitness are limited. In this paper, we present a set of wearable e-textile displays for running groups called Social Fabric Fitness (SFF). SFF provides a glanceable, shared screen on the back of the wearer's shirt to increase awareness and motivation of group fitness performance. We discuss parallel prototyping of three designs-one flexible e-ink and two flexible LED-based displays; the selection and refinement of one design; and two evaluations'a field study of 10 running groups and two case studies of running races. Our qualitative findings indicate that SFF improves awareness of individual and group performance, helps groups stay together, and improves in-situ motivation. We close with reflections for future athletic e-textile displays.
# https://dl.acm.org/doi/10.1145/3170427.3188623
# Textile production is a large and profitable industry that still struggles with issues relating to environmental impact and societal concerns like labour rights. Incorporating sustainable practices to reduce these issues will be highly beneficial for future generations. Potential measures exist on both an industry and company level, as well as in the purchase behaviour of individual consumers. We present Textile Manager, a persuasive game designed to encourage players to consider their own textile-related behaviour. Based on expert interviews, we discerned goals for a persuasive game to create awareness about issues in traditional textile production. Textile Manager presents a proof-of-concept prototype that was evaluated with a pre-post exposure study. We report findings regarding persuasive effect, voluntary information quests, and visualization of consequences for player decisions to contribute towards the persuasive technology research community.
# https://dl.acm.org/doi/10.1145/3305367.3327995
# Active Textile Tailoring is a new process for creating smart textiles in which its fibers change shape and structure in response to heat. This adaptive textile can create a new type of sizing customization or aesthetic patterning for the preference of individual customers. This system was developed in collaboration with MIT, Ministry of Supply, Hills Inc. and Iowa State University with support from the federal non-profit Advanced Functional Fabrics of America (AFFOA).
# https://dl.acm.org/doi/10.1145/1858171.1858257
# This workshop will explore the use of low-cost materials and tools to build textile-based interfaces that replace the current hard-shell computer mice or laptop touchpads that you use to navigate your screen. We will introduce a range of methods for handcrafting textile input devices. Participants will learn techniques developed by the workshop leaders and will also be encouraged to use our materials library to design their own custom mice. The goal of the workshop is to familiarize participants with available electronic textile materials, to introduce them to a variety of sensor and circuitry construction techniques and get people thinking about different interfaces that allow you interact differently with everyday technology.
# https://dl.acm.org/doi/10.1145/989863.989874
# Our studies have shown that as displays become larger, users leave more windows open for easy multitasking. A larger number of windows, however, may increase the time that users spend arranging and switching between tasks. We present Scalable Fabric, a task management system designed to address problems with the proliferation of open windows on the PC desktop. Scalable Fabric couples window management with a flexible visual representation to provide a focus-plus-context solution to desktop complexity. Users interact with windows in a central focus region of the display in a normal manner, but when a user moves a window into the periphery, it shrinks in size, getting smaller as it nears the edge of the display. The window "minimize" action is redefined to return the window to its preferred location in the periphery, allowing windows to remain visible when not in use. Windows in the periphery may be grouped together into named tasks, and task switching is accomplished with a single mouse click. The spatial arrangement of tasks leverages human spatial memory to make task switching easier. We review the evolution of Scalable Fabric over three design iterations, including discussion of results from two user studies that were performed to compare the experience with Scalable Fabric to that of the Microsoft Windows XP TaskBar.
# https://dl.acm.org/doi/10.1145/3306306.3338856
# This workshop will show how 3D printing with embedded fabric can be used for Cosplay & Fashion. These projects will inspire others to push the boundaries of how we use 3D printing.
# https://dl.acm.org/doi/10.1145/3406499.3418770
# With the influence of emerging digital technologies and digital fabrication techniques, textile craft practice has been evolving into new forms and dimensions interweaving digital and analog qualities. Fabric(a) project aims at experimenting with analogue and digital techniques to create new ways of crafting fabrics in a collective and interactive way. This paper addresses an experiment conducted in an open science event in order to co-craft a six-meter-long textile by two programmable drawing robots and human participants. The paper discusses how new interaction modalities between man-machine can alter the way we co-craft textiles and what kind of new ways of crafting might emerge from this collaboration
# https://dl.acm.org/doi/10.1145/1178823.1178880
# Mosaic Textile is a wearable ambient display using non-emissive color-changing textiles. The system consists of textile modules, their controllers and substrate fabric. The textile module is called "Fabcell" (fabric element) and is composed of conductive yarns and liquid crystal ink. Combining fabcells, as if they are used as pixels, produces real-space ambient display. Different from emissive flexible display such as organic EL, dynamic graphics using non-emissive color-changing textiles actualizes hospitable and aesthetic information display, blending in with environment. Our method will be expected to design brand-new communication media intended for fabric artificial materials, used for fashion and interior decoration.
# https://dl.acm.org/doi/10.1145/2641248.2666717
# A design concept for textile-electronics integration is presented. The design describes utilization of textile composites for building textile circuits. Customized electronic blocks are placed between two e-textile layers. Textile circuits are formed by contacting conductive threads and the unit blocks, without modifying the e-textile material. Routing of textile circuits using the proposed approach is shown in two examples.
# https://dl.acm.org/doi/10.1145/572020.572039
# As we face an increasingly heterogeneous collection of computational devices, there is a need to develop a general approach to what it is that we design as we create computational things. One such basic approach is to consider computational technology to be a design material. In the present paper, we describe how a traditional material --- textiles --- can be used to investigate aspects of the expressiveness and aesthetics of computational technology as design material. As an example of this approach, we use an experimental design project made for an art museum. We describe a series of conceptual sketches of how textile artefacts can be used to re-interpret elementary acts of information technology use and the experiences from working with the final installation of one of them. Finally, we discuss properties of textiles and computational technology, such as expressions related to vagueness, unpredictability and slowness.
# https://dl.acm.org/doi/10.1145/3334480.3382788
# The current work examines interactions that are enabled when depositing a human-safe hydrogel onto textile substrates. These hydrogel-textile composites are water-responsive, supporting reversible actuation. To enable these interactions, we describe a fabrication process using a consumer-grade 3D printer. We show how different combinations of printed hydrogel patterns and textiles create a rich actuator design space. Finally, we show an application of this approach and discuss opportunities for future work.
# https://dl.acm.org/doi/10.1145/2893499
# 3-D printed objects made of fabric could be flexible and deformable, bringing possibilities to new sensors and actuators.
# https://dl.acm.org/doi/10.1145/2370216.2370348
# Stitched e-textile circuits facilitate wearable, flexible, comfortable wearable technology. However, while stitched methods of e-textile circuits are common, multi-layer circuit creation remains a challenge. Here, we present methods of stitched multi-layer circuit creation using accessible tools and techniques.
# https://dl.acm.org/doi/10.1145/1709886.1709972
# This workshop will explore the use of low-cost materials and tools to build textile-based interfaces. We will introduce a range of methods for handcrafting textile sensors and circuitry. Participants will learn techniques developed by the workshop leaders and will also be encouraged to use our material library to design their own custom sensors. The goal of the workshop is to familiarize participants with available electronic textile materials and introduce them to a variety of sensor and circuitry construction techniques.
# https://dl.acm.org/doi/10.1145/3027063.3052972
# This abstract introduces a set of tools for electronic textile crafts. The goal is to combine established textile craft routines with electronic functionalities while avoiding being limited to either crafting or engineering qualities. A discipline's toolset is decisive in what material can be handled and what output can be produced as well as the skills needed to handle it. New tools presented here allow for new interactions with materials and make new routines accessible to the processes of electronic making and textile crafting, potentially being inclusive to new user groups in the respective fields. Here, traditional needlecraft tools are adapted to integrate electric engineering needs. Functionally, these tools augment processes of textile crafting with information about electric properties of the artifact in production. More broadly, they are a chance to reflect on the roles and cultural assumptions of the technologies, and indeed crafts, that these tools enable.
# https://dl.acm.org/doi/10.1145/3472749.3474766
# People often have to remove their phone from an inaccessible location like a pocket to view things like notifications and directions. We explore the idea of viewing such information through the fabric of a pocket using low resolution bright LED matrix displays. A survey confirms viewing information on inaccessible phones is desirable, and establishes types of pockets in garments worn by respondents and what objects are typically put in pockets. A technical evaluation validates that LED light can shine through many common garment fabrics. Based on these results, functional hardware prototypes are constructed to demonstrate different form factors of through-fabric display devices, such as a phone, wallet, a key fob, a pen, and earbud headphone case. A simple interaction vocabulary for viewing key information on these devices is described, and the social and technical aspects of the approach are discussed.
# https://dl.acm.org/doi/10.1145/3306346.3322988
# We present an inverse design tool for fabric formwork - a process where flat panels are sewn together to form a fabric container for casting a plaster sculpture. Compared to 3D printing techniques, the benefit of fabric formwork is its properties of low-cost and easy transport. The process of fabric formwork is akin to molding and casting but having a soft boundary. Deformation of the fabric container is governed by force equilibrium between the pressure forces from liquid fill and tension in the stretched fabric. The final result of fabrication depends on the shapes of the flat panels, the fabrication orientation and the placement of external supports. Our computational framework generates optimized flat panels and fabrication orientation with reference to a target shape, and determines effective locations for external supports. We demonstrate the function of this design tool on a variety of models with different shapes and topology. Physical fabrication is also demonstrated to validate our approach.
# https://dl.acm.org/doi/10.1145/3357236.3395447
# In this paper we investigate how a combination of "speculative" design methods can be used to generate theoretical understandings for dynamic, colour-changing fabrics for garments. Specifically, we combine a first-person, autobiographical, research through design (RtD) approach that draws strategies from speculative design. We call this approach alternative presents, inspired by the work of James Auger, and explore it as a way to generate theoretical propositions for dynamic fabric that emphasize the lived experience over technological innovation. The contributions of this framing are twofold. Firstly, we offer a theoretical contribution to the literature on dynamic fabric. Secondly, we make a methodological contribution for how autobiographical design and RtD can be oriented speculatively to generate intermediate knowledge, with particular emphasis on social-technical aspects.
# https://dl.acm.org/doi/10.1145/3349263.3349598
# Currently, interactive devices can easily disappear into a wide range of physical context due to the development of microcontrollers, sensors and actuators. However, this disappearing interaction scenario may cause confusion to the users regarding where and how to interact with it. Therefore, a research project has been conducted to investigate different inherent feedforwards for this disappearing interaction scenario in textile surfaces. A Tangible User Interface (TUI) for volume adjusting was designed, which can provide both visual and shape-changing feedforwards. This interface can be implemented in ubiquitous soft surfaces, in this demo, a textile-based Human-Machine Interaction (HMI) in the vehicle seat. The textile interface provides a both natural and enjoyable HMI concept. This report describes the theoretical background, prototype, user test and demo setup and contribution.
# https://dl.acm.org/doi/10.1145/3430524.3446069
# Invested in increasing access to computational literacy, this paper explores the development of a series of free public workshops in partnership with an equity-seeking group. These workshops cover e-textile techniques that lend themselves to making alternative game controllers leading up to a concept-led game jam. We use research creation approaches to prioritize creative exploration within a community group for marginalized makers. The goal of the research is to explore and elucidate the overlap between e-textiles and experimental game making. We discuss our playful use of workshops as research method to iterate on the embodied experience of making on behalf of our participants. Our contribution maps the connections between workshop design and development, learning materials generated, through to application within an online game jam setting.
# https://dl.acm.org/doi/10.1145/2668956.2668959
# The virtual world is currently limited in the graphic representation and visualization of material designs. The limitation is in part due to the limited range and the relative simplicity of spectral properties of the materials simulated in a virtual environment. Our work starts with a fast classification and retrieval for handling the large numbers of multi-scale texture samples of complex deformable materials, such as, woven and knitted fabrics. We have developed a general system that can also serve as a unified platform for other material analysis and classification and a 3D panel design system for 3D clothing modeling and draping. Multi-scale color theme indexing for image acquisition and retrieval can be more intuitively supported by a multi-touch gesture interface that is now the preferred mode of interacting with tablets, screens, and other visual communication devices. These also add to the collaborative modes of input and retrieval in fabric and fashion design for virtual agents. In this paper we describe the process of texture analysis of real fabric materials and preliminary models for the 3D texture generation for virtual clothing, color theme design, and ultimately 3D draping based on robust collision detection methods.
# https://dl.acm.org/doi/10.1145/3332165.3347896
# We present a technique for fabricating soft and flexible textiles using a consumer grade fused deposition modeling (FDM) 3D printer. By controlling the movement of the print header, the FDM alternately weaves the stringing fibers across a row of pillars. Owing to the structure of the fibers, which supports and strengthens the pillars from each side, a 3D printer can print a thin sheet of fabric in an upright position while the fibers are being woven. In addition, this technique enables users to employ materials with various colors and/or properties when designing a pattern, and to prototype an interactive object using a variety of off-the-shelf materials such as a conductive filament. We also describe a technique for weaving textiles and introduce a list of parameters that enable users to design their own textile variations. Finally, we demonstrate examples showing the feasibility of our approach as well as numerous applications integrating printed textiles in a custom object design.
# https://dl.acm.org/doi/10.1145/3569551.3569557
#  The textile sector is one of the vital driving forces in the economy of south Asian countries like Bangladesh, India, Pakistan, etc. However, most of the textile industries suffer from frequent machinery faults everyday which reduces their productivity, which in terms reduces their profit. Existing systems for detecting the faults in textile machinery fails to find a remedy to this problem due to several limitations. Among them, sound based and vibration based fault detection systems are based on prototype machinery and has smaller data set to detect machinery fault properly. The fabric defect based, machine learning based approaches only detect machinery fault after fabric has become already defected. To remedy these limitations, in this paper, we propose a sound based fault detection system consisting of trained machine learning model from large data set that can detect machinery fault in textile industry. We use a sound sensor to measure the sound signal of the machine. We artificially create three real faults in the experimented machine and measure the sound signal during the faults. Next, we conduct Fast Fourier Analysis derive sound frequency and statistical analysis to derive different statistical features from the prepared data set. From these two analysis, we determine if the sound frequency and amplitude changes during the fault. After that, we feed the data set to ten machine learning algorithms. Finally, we evaluate our trained machine leaning models through ten fold cross validation to determine the precision, recall, and F1 score. We find the highest F1 of 57.7% in Nearest Centroid Algorithm.
# https://dl.acm.org/doi/10.1145/3282286.3282300
# In this paper, Fabric defect detection is a challenging task because of the complex texture. Deep learning technology provide a promising solution. As a kind of deep learning object detection model. Single Shot Multibox Detector(SSD)achieves good detection performance. However, the original SSD model may fail to detect the small objects. In this paper, we proposed a novel SSD model for fabric defect detection. Experimental results showed that the improved SSD model can accurately detect the defect region.
# https://dl.acm.org/doi/10.1145/3490149.3505577
#  In this study, we propose the design and implementation of a smart textile using conductive sequins produced by a 3D printer based on traditional sequin embroidery.  The well-designed conductive sequin smart textile, referred to as traditional sequin embroidery of various designs and diverse embroidery techniques, can break through the limitations of sequin fabric in its vertex modeling capability to create vertex-like sequins.  Using conductive and non-conductive resins, we printed out two types of sequins using a 3D printer1, which are then combined and embroidered using the traditional sequin embroidery technique. When a force such as a touch or press is applied to the conductive sequins, a signal generated from the circuit, which those sequins themselves are part of, will be sent to the computer. The computer can visualize the electric signals of this textile and sense the changes in the state of the textile.
# https://dl.acm.org/doi/10.1145/3559400.3562001
# Printing-on-fabric is an affordable and practical method for creating self-actuated deployable surfaces: thin strips of plastic are deposited on top of a pre-stretched piece of fabric using a commodity 3D printer; the structure, once released, morphs to a programmed 3D shape. Several physics-aware modeling tools have recently been proposed to help designing such surfaces. However, existing simulators do not capture well all the deformations these structures can exhibit. In this work, we propose a new model for simulating printed-on-fabric composites based on a tailored bilayer formulation for modeling plastic-on-top-of-fabric strips, and an extended Saint-Venant–Kirchhoff material law for modeling the surrounding stretchy fabric. We show how to calibrate our model through a series of standard experiments. Finally, we demonstrate the improved accuracy of our simulator by conducting various tests.
# https://dl.acm.org/doi/10.1145/3123021.3123058
# Stitched methods of e-textile fabrication offer durability and flexibility benefits, as well as relatively un-constrained layout patterns. The ability to affix discrete component packages without a PCB substrate would improve the overall flexibility and comfort of an e-textile garment. However, that level of integration between electronic and apparel manufacturing processes is difficult to achieve. Here we present the development of a stitched method of fabricating e-textile circuits with surface-mount components. The technique leverages technologies and methods common to sewn product manufacturing. Using a simulated high-intensity wear test, we evaluate the durability of this method for circuit architecture variables of component size, trace width, and trace orientation, as well as for methodological variables of solder deposition technique and reflow process. We show durability of 3% failure after a 14-hour wear test for the best manufacturing conditions. Further, we implement the manufacturing technique in an LED matrix display application.
# https://dl.acm.org/doi/10.1145/2069618.2069692
# We examine e-textile designs, a new domain combining crafts, circuitry, and programming with the LilyPad Arduino, to better understand how novice designers develop creative technical solutions. Our analyses draw from observation and interviews conducted with middle and high school students enrolled in e-textiles workshops. In the workshops, students created their own designs by re-interpreting e-textile creations from an online community or by re-purposing the conductive functionality of everyday objects. These remixes, popular in today's youth digital media culture, can also be seen as "interpretative flexibility" and promising indicators of the everyday creativity of novice designers.
# https://dl.acm.org/doi/10.1109/DATE.2005.138
# As the scale of electronic devices shrinks, "electronic textiles" (e-textiles) will make possible a wide variety of novel applications which are currently unfeasible. Due to the wearability concerns, low-power techniques are critical for e-textile applications. In this paper, we address the issue of the energy-aware routing for e-textile platforms and propose an efficient algorithm to solve it. The platform we consider consists of dedicated components for e-textiles, including computational modules, dedicated transmission lines and thin-film batteries on fiber substrates. Furthermore, we derive an analytical upper bound for the achievable number of jobs completed over all possible routing strategies. From a practical standpoint, for the Advanced Encryption Standard (AES) cipher, the routing technique we propose achieves about fifty percent of this analytical upper bound. Moreover, compared to the non-energy-aware counterpart, our routing technique increases the number of encryption jobs completed by one order of magnitude.
# https://dl.acm.org/doi/10.1145/2641248.2641276
# The E-Textile Swatch Exchange is a platform for sharing physical work samples in the field of electronic textiles. The exchange wishes to emphasize the importance of physicality and quality workmanship in an increasingly digital world. Individuals and collaborative efforts participate in the exchange by submitting a unique swatch design of their own, and in turn receive a compiled collection of everybody else's swatches. This means that everybody participating needs to make as many multiples of their swatch as the total number of participants. There are no guidelines defining what the swatches could or should be, only that they relate to the field of E-Textiles.
# https://dl.acm.org/doi/10.1145/3544794.3560293
# We demonstrate a modular e-textile sports garment with the ability to house different types of sensors, using temperature sensing as an example. To connect circuit modules, flexible interposers are used to create interfaces between materials which are difficult to join reliably, and a modular design is used so that a) the system can be disassembled for repair or recycling, and b) electronic and textile parts are fabricated separately and integrated only at the final assembly stage. This aims to simplify manufacturing and to facilitate separation at end of life for recycling, updating or reuse. The focus of this paper is stress testing the system to show that the prototype modular garment can survive repeated bending and stretching, and that the system can record skin temperature with sufficient accuracy.
# https://dl.acm.org/doi/10.1145/3544549.3582736
# Body-centric design disciplines that utilize digitization processes such as fashion are tasked to engage with theoretical concepts commonly applied in digital-native design disciplines in order to use digital technologies as more than simple tools. Guided by intra-action theory, alternative ontological and hierarchical relations between the body and textiles were explored by digitally translating their movement. An installation was developed to find hybrid body-textile expressions using motion-capture sensors and robotic arms. The findings suggest that technological augmentations of the body and textiles can increasingly be diffracted in terms of their apparent physical-material boundaries through movement translation. Movement data functioned as a performative mediator, expanding movement-based expressions from one agent to another. Body-textile hybrids emerged from this process, and shaped each other in a mutual act of becoming, challenging ontological structures of the body and textiles commonly applied in fashion design.
# https://dl.acm.org/doi/10.1145/3544549.3582736
# Body-centric design disciplines that utilize digitization processes such as fashion are tasked to engage with theoretical concepts commonly applied in digital-native design disciplines in order to use digital technologies as more than simple tools. Guided by intra-action theory, alternative ontological and hierarchical relations between the body and textiles were explored by digitally translating their movement. An installation was developed to find hybrid body-textile expressions using motion-capture sensors and robotic arms. The findings suggest that technological augmentations of the body and textiles can increasingly be diffracted in terms of their apparent physical-material boundaries through movement translation. Movement data functioned as a performative mediator, expanding movement-based expressions from one agent to another. Body-textile hybrids emerged from this process, and shaped each other in a mutual act of becoming, challenging ontological structures of the body and textiles commonly applied in fashion design.
# https://dl.acm.org/doi/10.1145/2968219.2979142
# Textile Thinking and Ultra Personalization are guiding the PhD research in wearable on body sensing in the creation of garments / accessories. Textile Thinking involves the superficial surface of a design process that attempts to create a point of view to reach new understandings in design and architecture. When applied to interaction design in the near field the garments that people wear can become an interface or expression for sensing and actuating. Specific ideas such as Fit are explored to aid in developing a more unique understanding of interaction on the body.
# https://dl.acm.org/doi/10.1145/3544548.3581343
# Hand edema, defined as swelling of the hands caused by excess fluid accumulation, is a pervasive condition affecting a person’s range of motion and functional ability. However, treatment strategies remain limited to time-consuming manual massage by trained therapists, deterring a widely accessible approach. We present KnitDema, a robotic textile device that allows sequential compression from distal to proximal finger phalanges for mobilizing edema. We machine-knit the device and integrate small-scale actuators to envelop granular body locations such as fingers, catering to the shape of the hand. In addition, the device affords customizable compression levels through the enclosed fiber-like actuators. We characterize compression parameters and simulate the shunting of edema through a mock fluid system. Finally, we conduct a case study to evaluate the feasibility of the device, in which five hand edema patients assess KnitDema. Our study provides insights into the opportunities for robotic textiles to support personalized rehabilitation.
# https://dl.acm.org/doi/10.1145/2800835.2800936
# This paper describes the creation of a woven two-layer fabric, created using two-warp system. The fabric is designed to contain components inside the two layers, with the power supply signals on top- and bottom-layers. The surface mounted components are prepared for weaving by adding long insulated threads, to be partially removed accordingly just before integrating to the fabric. The final fabric contains a working circuit for detecting magnetic fields as an example implementation.
# https://dl.acm.org/doi/10.1145/3526113.3545688
#  In this research, we used traditional sequin embroidery as the basis and a 3D printer to expand the design space of sequin materials and structures, by developing a new 2.5D smart conductive sequin textile with multiple sensing and interactions as well as providing users with a customizing system for automated design and manufacturing.  Through 3D printing, we have developed a variety of 3D sequins. We used each sequin as an individual design unit to realize various circuit designs and sensing functions by adjusting the design primitives such as conductivity, shape, and arrangement. We also designed applications such as motion sensing of body movements, and posture detection of the ankle. In addition, we surveyed user requirements through user testing to optimize the design space.  This paper describes the design space, design software, automation, application, and user study of various smart sequin textiles.
# https://dl.acm.org/doi/10.1145/2993148.2998520
#  In this study, we developed a telepresence system which has a flexible and deformable screen. The screen deforms in synchronization with the move of the objects on the projected video. This deformation of the display surface provides the perception of depth for the projected video. We attempted to add the perception of depth to the video of the remote person and extend a video conferencing system. The results of the experiment suggested that the perception of depth provided by system strengthens the presence of a remote person and an object on the video.
# https://dl.acm.org/doi/10.1145/3126594.3126620
# This paper enables data storage and interaction with smart fabric, without the need for onboard electronics or batteries. To do this, we present the first smart fabric design that harnesses the ferromagnetic properties of conductive thread. Specifically, we manipulate the polarity of magnetized fabric and encode different forms of data including 2D images and bit strings. These bits can be read by swiping a commodity smartphone across the fabric, using its inbuilt magnetometer. Our results show that magnetized fabric retains its data even after washing, drying and ironing. Using a glove made of magnetized fabric, we can also perform six gestures in front of a smartphone, with a classification accuracy of 90.1%. Finally, using magnetized thread, we create fashion accessories like necklaces, ties, wristbands and belts with data storage capabilities as well as enable authentication applications.
# https://dl.acm.org/doi/10.1145/3594739.3610717
# A common method of generating a garment pattern is by draping fabric on a 3D form. Many apparel designers prefer this tangible process rather than the more abstract process of drafting patterns in 2D using CAD software, but the visualization benefits of 3D rendering remain important to product development. Currently, draped patterns must be manually digitized to transfer the shape to the CAD environment, a cumbersome process. Here, we explore augmenting the fabric used to drape patterns with e-textile components, such that pinning the fabric to the form directly digitizes the pattern shape. The e-textile interface uses a keypad matrix approach with rows and columns on opposite sides of the fabric. Passing a metallic pin through a row/column intersection creates a circuit connection that a microcontroller reads and maps to a 2D spatial layout on the screen. The proof-of-concept device developed here is a first step toward an automatic digitizing system that allows designers to preserve manual skills and processes while integrating more efficiently with digital systems.
# https://dl.acm.org/doi/10.1145/3173225.3173255
# We introduce and discuss the design and use of new tools for electronic textile making. Electronic textiles, or eTextiles, are increasingly produced and used in experimental interfaces, wearables, interior design, as well as in the education and maker cultures. However, the field relies on tools specific to either the textile or the electronic domain, neglecting the distinct requirements, and potentials, of their intersection. To address this gap, we explored the design of new tools, targeted at specific needs and use cases of electronic textile making and the materials used. Three resulting prototypes have been evaluated through use in both our own practice and among a group of experts in the field. Our findings show the importance of specialized tools for routines essential to the field eTextiles, their role for the emergence of new practices, as well as for the understanding of the discipline.
# https://dl.acm.org/doi/10.1145/3267242.3267281
# Muscle fatigue monitoring is important for injury prevention in sports. Previous studies have shown that wearable electromyography (EMG) sensors on limb muscles can be used to monitor the level of muscle fatigue continuously. However, there are two main problems in using these sensors for sports. One is that users wearing them create motion artifacts that affect the sensor data. The other is that the sensors disturb limb motion. To address these problems, we propose a method for estimating biceps fatigue with an e-textile headband. There is a strong correlation between frowning and jaw clenching muscle activity and the physical efforts made when exercising. Our method uses both of EMG signals of the temporal muscles and motion artifacts. The former indicate jaw clenching and the latter indicate frowning. Experimental results show that the root mean square values calculated from the headband sensor values significantly increased when biceps were fatigued.
# https://dl.acm.org/doi/10.1145/3064857.3079181
# Electronic textiles worn on the body provide interesting opportunities for ambient notification within assistive systems, as they can be seamlessly integrated into everyday clothing and accomodate for completely private modalities, such as thermohaptic feedback. In this paper, we present three different approaches to wearable ambient notification systems in textile for elderly users. We have constructed three interactive shawls, exploring how different outputs for ambient notification can be integrated into industrially knitted fabric. We describe the design process of the prototypes, present the challenges in constructing them and discuss their implications as ambient notification devices.
# https://dl.acm.org/doi/10.1145/3430524.3440642
#  E-textiles, which embed circuitry into textile fabrics, blend art and creative expression with engineering, making it a popular choice for STEAM classrooms [6, 12]. Currently, e-textile development relies on tools intended for traditional embedded systems, which utilize printed circuit boards and insulated wires. These tools do not translate well to e-textiles, which utilize fabric and uninsulated conductive thread. This mismatch of tools and materials can lead to an overly complicated development process for novices. In particular, rapid prototyping tools for traditional embedded systems are poorly matched for e-textile prototyping. This paper presents the ThreadBoard, a tool that supports rapid prototyping of e-textile circuits. With rapid prototyping, students can test circuit designs and identify circuitry errors prior to their sewn project. We present the design process used to iteratively create the ThreadBoard’s layout, with the goal of improving its usability for e-textile creators.
# https://dl.acm.org/doi/10.1145/2493988.2494355
# In this paper we describe a novel method for detecting bends and folds in fabric structures. Bending and folding can be used to detect human joint angles directly, or to detect possible errors in the signals of other joint-movement sensors due to fabric folding. Detection is achieved through measuring changes in the resistance of a complex stitch, formed by an industrial coverstitch machine using an un-insulated conductive yarn, on the surface of the fabric. We evaluate self-intersecting folds which cause short-circuits in the sensor, creating a quasi-binary resistance response, and non-contact bends, which deform the stitch structure and result in a more linear response. Folds and bends created by human movement were measured on the dorsal and lateral knee of both a robotic mannequin and a human. Preliminary results are promising. Both dorsal and lateral stitches showed repeatable characteristics during testing on a mechanical mannequin and a human.
# https://dl.acm.org/doi/10.1145/2634317.2634326
# An effective way to monitor body movements and positions (including physiological signals like breathing) without causing discomfort is through integration of sensors and electronics into base layers of clothing. However, for many applications (including sports and fitness), such sensors must be washable. Here, we present results of experiments evaluating the impact of washing on an e-textile stretch and bend sensor. Two cases are investigated: un-insulated sensors and sensors insulated with a fusible polymer film. Results show small-scale drift in the un-insulated sensor, which is magnified by machine washing and further by machine drying. Similar results are observed in delamination effects for the insulating film.
# https://dl.acm.org/doi/10.1145/1935701.1935715
# This paper explores the idea of handcrafted electronics. We introduce a kit-of-no-parts approach to building electronics from a diverse palette of craft materials, which we argue is more personal, understandable and accessible than the construction of technology from a kit of pre-determined components. We illustrate our approach by describing the design, construction, and dissemination of a collection of textile sensors, and detailing a website and a series of workshops through which we share our approach.
# https://dl.acm.org/doi/10.1145/2857546.2857621
# In this paper, we present a configuration of a textile antenna for wearable applications with Radio Frequency Identification (RFID) technology. This antenna operates at a frequency of 2.45GHz and it is composed of a radiation structure with only one layer of dielectric. The dielectric used for simulation is a Kevlar substrate having a dielectric constant of εr= 3.58 and a thickness of h=0.254 mm. This material satisfies the requirements of flexibility of the wearable antenna. The radiating element designed in the form of text is the abbreviation of the Hanoi University of Science and Technology (HUST). The substrate has the dimension L=45mm and W=16mm. The radiation element is simulated with copper material. This antenna is designed and simulated by using the commercial software CST Microwave Studio. The simulated reflection coefficient S11 is -18.26dB and the gain of 2.085dB.
# https://dl.acm.org/doi/10.1145/3563657.3596086
# A woven textile-form is a form that is constructed simultaneously as the textile is woven. Interfaces designed with this approach hold undisclosed potential for rich interactions. However, the design of woven textile-form interfaces requires specialised tacit knowledge, which is limited even in craft and practice spaces; and it is therefore inaccessible to HCI designers. To bridge this gap, we present the material-driven journey of a multidisciplinary team to design a woven textile-form interface using various techniques such as paper models and diagrams to design for multi-layer weaving. Replacing traditional yarns with conductive yarn, we achieved woven textile-forms with electronic sensing capabilities. By outlining our process, the pictorial highlights the challenges and opportunities of textile-form thinking for HCI designers. Additionally, its printed version serves as a ‘paper prototyping tool’ for designers to gain hands-on experience developing textile-form interfaces.
# https://dl.acm.org/doi/10.1145/3544549.3583899
# In the field of physiotherapy and rehabilitation, location-independent training has gained importance. We present the further development of a wearable for this purpose including gamification to improve successful training. A wearable was developed to increase the motivation of patients to perform their prescribed physical therapy exercises at home. Extending a pair of smart trousers [12], smart knee pads connected to a gaming app were developed. A comparative qualitative study was conducted in order to explore how users react to playing a game as an extension of their physiotherapy session. The results of the user test show that the majority of respondents consider technology-enabled training to be helpful for their therapy success. Aspects of a "playful approach" and "competition" were named as the main motivating factors for the use of wearables in a therapy context. However, "competition" was only rated positively by male participants.
# https://dl.acm.org/doi/10.1145/3123024.3123151
# A tear of the Anterior Cruciate Ligament (ACL) is a severe knee injury that requires up to a year of rehabilitation. Patients sustaining an ACL injury perform rehabilitation exercises mostly at home unsupervised. Orthopedists meet patients at time intervals as long as three months and lack quantitative ways to measure and keep track of the rehabilitation progress of each patient during these intervals. We present KneeHapp, a smart bandage and sock to support and keep track of the rehabilitation progress after an ACL injury. KneeHapp measures the quality of different ACL rehabilitation exercises and provides feedback to patients and orthopedists. We describe in detail how we constructed KneeHapp making use of smart textile technologies and provide insight into its software and quality of its measurements.
# https://dl.acm.org/doi/10.1145/3430524.3440633
#  As technology is integrated into all aspects of our lives, researchers are exploring emerging technologies in the field of fashion design. The substantial growth in the field of functional apparel design, such as the use of smart textiles, encourages researchers and fashion designers to incorporate technology within their designs. In much previous work, e-textiles have required interdisciplinary knowledge such as electrical engineering and computer science to be successful. To help with this we created ready-to-use shape changing fabric samples for fashion designers. We explored this research gap through a preliminary user case study with seven experienced designers. Our results suggest design approaches for shape changing fabric samples that would assist non-technically skilled designers incorporating technology in their designs.
# https://dl.acm.org/doi/10.1145/3461778.3462139
# ...
# https://dl.acm.org/doi/10.1145/1979742.1979707
# We present an electronic game of tag that uses proximity sensing and Lumalive displays on garments. In our game of tag, each player physically represents a location-tagged Universal Resource Indicator (URI). The URIs, one chaser and two target players, wear touch-sensitive Lumalive display shirts. The goal of the game is for the chaser to capture a token displayed on one of the Lumalive shirts, by pressing a touch sensor located on the shirt. When the chaser is in close proximity to the token player, the token jumps to the shirt of the second closest player, making this children's game more challenging for adult players. Our system demonstrates the use of interactive e-textile displays to remove the technological barrier between contact and proximity in the real world, and the seamless representation of gaming information from the virtual world in that real world.
# https://dl.acm.org/doi/10.1145/3580883
# We present MoCaPose, a novel wearable motion capturing (MoCap) approach to continuously track the wearer's upper body's dynamic poses through multi-channel capacitive sensing integrated in fashionable, loose-fitting jackets. Unlike conventional wearable IMU MoCap based on inverse dynamics, MoCaPose decouples the sensor position from the pose system. MoCaPose uses a deep regressor to continuously predict the 3D upper body joints coordinates from 16-channel textile capacitive sensors, unbound by specific applications. The concept is implemented through two prototyping iterations to first solve the technical challenges, then establish the textile integration through fashion-technology co-design towards a design-centric smart garment. A 38-hour dataset of synchronized video and capacitive data from 21 participants was recorded for validation. The motion tracking result was validated on multiple levels from statistics (R2 ~ 0.91) and motion tracking metrics (MP JPE ~ 86mm) to the usability in pose and motion recognition (0.9 F1 for 10-class classification with unsupervised class discovery). The design guidelines impose few technical constraints, allowing the wearable system to be design-centric and usecase-specific. Overall, MoCaPose demonstrates that textile-based capacitive sensing with its unique advantages, can be a promising alternative for wearable motion tracking and other relevant wearable motion recognition applications.
# https://dl.acm.org/doi/10.1145/3123021.3123068
# We present "hitoeCap", which has Poly(3,4-ethylenedioxythiophene)-poly(styrenesulfonate) (PEDOT-PSS) textile electrodes for measuring electromyography (EMG) of the masticatory muscles. Masticatory muscle activity is relevant to several daily activities such as diet, sleep bruxism, and human motor control. Our aim is to leverage continuous EMG data of the masticatory muscles for monitoring daily activities. For motion artifact reduction, which is a major problem for measuring EMG with textile electrodes, we propose a new algorithm based on kinesiology by utilizing a correlation coefficient between the root mean square of the right side EMG and that of the left side EMG. We have developed a hitoeCap prototype and conducted experiments to verify the usability of the PEDOT-PSS electrodes and the feasibility of our proposed algorithm.
# https://dl.acm.org/doi/10.1145/3242587.3242664
# We present RESi (Resistive tExtile Sensor Interfaces), a novel sensing approach enabling a new kind of yarn-based, resistive pressure sensing. The core of RESi builds on a newly designed yarn, which features conductive and resistive properties. We run a technical study to characterize the behaviour of the yarn and to determine the sensing principle. We demonstrate how the yarn can be used as a pressure sensor and discuss how specific issues, such as connecting the soft textile sensor with the rigid electronics can be solved. In addition, we present a platform-independent API that allows rapid prototyping. To show its versatility, we present applications developed with different textile manufacturing techniques, including hand sewing, machine sewing, and weaving. RESi is a novel technology, enabling textile pressure sensing to augment everyday objects with interactive capabilities.
# https://dl.acm.org/doi/10.1145/2512349.2512813
# In this paper we propose a new technology of touch sensitive textile displays that can detect touch without adding additional sensors to a thermochromic inks and peltier semi-conductor display system. Without any changes to the hardware of the display, we present a method to modify the existing temperature controllers of pelter elements to detect impulse temperature transients that are caused through touch. Using this method, the textile display can become a touch sensitive interactive textile display. We present the results of this system and two application prototypes that enhance simple table cloths into ubiquitously becoming a tic-tac-toe gaming platform and an interactive drawing pad with touch sensing. In addition, our user evaluations to observe the robustness and the performance of the system indicate that the system is detects touch at acceptably high speeds. In addition, the system performance is independent of the ambient temperature and depends mainly on the temperature of the finger.
# https://dl.acm.org/doi/10.1145/3197391.3205382
# Many smart clothing concepts are appearing in research and industry, encompassing disparate disciplines, inhabiting many forms. However, few situated in the Internet of Things (IoT) ecology. Moreover, adding wireless data processing capability can extend their functionality. Highly stylized, speculative, wearable technology (wearables) garments with technologically augmented function (c.f.[1]) have been difficult to place into a broader social context as fashion.
# https://dl.acm.org/doi/10.1145/2971763.2971784
# In this paper we present a smart soccer shoe that uses textile pressure sensing matrices to detect and analyze the interaction between players' foot and the ball. We describe the sensor system that consists of two 3 × 4 and one 3 × 3 matrices sampled at over 500Hz with low power electronics that allows continuous operation (incl. wireless transmission) for 8 hours using a small 800mA/h Li-Po battery. We show how relevant parameters for shot analysis such as contact speed and contact angles can be reliably derived from the sensor signals. To ensure reliable ground truth we evaluated the system with a kick robot in the adidas testing facility, which is the standard approach used by adidas to systematically and quantitatively test new shoes and balls. The test encompasses 17 different types of shots and achieves a near 100% classification accuracy/F-score. The system endured extreme levels of impact resulting in over 100km/hr ball speed.
# https://dl.acm.org/doi/10.1145/2800835.2807931
# Wearable technology projects sometimes present complex problems, which are hard to solve through computer science solutions alone. Our interdisciplinary team met such a problem in the form of near infrared sensor noise due to fabric interference. We met the challenge through software/hardware solutions, but also strategic fabric selection and soft-good construction. This case study shows how incorporating everyone's expertise on an interdisciplinary team can afford solutions, which better accomplish the goals of a project than individual disciplines could alone.
# https://dl.acm.org/doi/10.1145/3290607.3312857
# In-situ exploration of heart rate (HR) zones during cardio training (CT) is important for training efficiency. However, approaches for monitoring HR, either depend on complex visualizations on small screens (i.e., smartwatches) or intrusive modalities (i.e. haptic, auditory) that might force the attention to the information. We developed an early prototype, Howel, a novel wrist-worn soft wearable to display HR zone information during CT. Our concept utilizes mapping information onto dynamic patterns (color changing stripes) as an easy-to-understand ambient display. To preserve non-intrusiveness, it uses non-emissive modality by heating thermochromic paints on its textile surfaces. Early feedback from three participants suggests that soft wearables with non- emissive dynamic patterns have potential (1) to embed information organically on the body, (2) to give easy-to-understand in-situ intensity information and (3) to keep the attention on the exercise instead of performance measures.
# https://dl.acm.org/doi/10.1145/2700648.2811355
# Children with autism found free play difficult. Free play is important for children with autism to help them develop social, communication, and expression skills. Interactive surfaces (IS) offer a casual and natural collaborative and engaging experience adequate to promote free play for children with autism. In this poster, we present the design and development of BendableSound, a fabric-based IS that allows children play music when tapping and touching on digital elements appearing on top of the fabric. To design BendableSound, we followed a user-centered design process involving interviewing, observation, and design sessions with caregivers. We close discussing directions for future work.
# https://dl.acm.org/doi/10.1145/2347504.2347542
# Interactive interiors which are customizable to the design preferences and functional purposes of individual users can help create flexible interiors within fixed spaces. They are particularly relevant to densely populated cities where most people live in compact spaces. This proposed research explores interactive interior textile surfaces as an adaptive media which can transform interiors via the change of colors, luminescence and surface design. This is done by investigating the integration of textile base material via embellishment techniques, such as embroidery and felting, with polymeric photonic fibers (POF) which enhance tactile quality without compromising on the technological functionality. Their flexible application methods mean that, it is adaptable to the rigid nature of polymeric photonic fibers. In addition, embroidery has the unique ability to arrange and combine threads together with various materials in non-rigid formations and multiple directions to create stable two-dimensional and three-dimensional forms [1]. Different materials can be combined to explore aesthetically pleasing surface designs, textures and achieve positive tactile quality.
# https://dl.acm.org/doi/10.1145/3610927
# Cycling is an efficient and effective way to improve one's overall fitness level, such as cardiovascular fitness, stamina, lower body strength, and body fat percentage. To improve fitness performance, real-time cycling fitness tracking can not only allow cyclists to better control their energy outputs but also help push workout intensity and keep users accountable for their fitness progress. However, existing bike sensors (e.g., the ones mounted to bike's wheel hub or crank arm) are only limited to measuring cycling cadence and speed. Although several recent studies relying on on-body sensors or cameras can provide more fine-grained information (e.g., riding position and knee joint angle), they would either require inconvenient setups or raise serious privacy concerns. To circumvent these limitations, in this paper, we propose SmarCyPad, an innovative smart seat pad that can continuously and unobtrusively track five cycling-specific metrics, including cadence, per-leg stability, leg strength balance, riding position, and knee joint angle of the cyclist. Specifically, we embed conductive fabric sensors in the seat pad to sense the pressure applied to the bike's seat exerted by the cyclist's gluteal muscles. A series of signal processing algorithms are developed to estimate the pedaling period from the sensed pressure signal and further derive the cycling cadence, per-leg stability, and leg strength balance. Additionally, we leverage a deep learning model to detect the cyclist's riding position and reconstruct the cyclist's knee joint angles via linear regression. The sensors and the system prototype are manufactured from scratch leveraging off-the-shelf materials, and the total cost is less than $50. Extensive experiments involving 15 participants demonstrate that SmarCyPad can accurately estimate the cycling cadence with an average error of 1.13 rounds per minute, quantify the cycling stability for each leg, detect cycling imbalance, distinguish five riding positions with an accuracy of 96.60%, and continuously track the knee joint angle with an average mean error as low as 9.58 degrees.
# https://dl.acm.org/doi/10.1145/2771839.2771883
# Electronic textile (e-textile) toolkits have been successful in broadening participation in STEAM-related activities, in expanding perceptions of computing, and in engaging users in creative, expressive, and meaningful digital-physical design. While a range of well-designed e-textile toolkits exist (e.g., LilyPad), they cater primarily to adults and older children and have a high barrier of entry for some users. We are investigating new approaches to support younger children (K-4) in the creative design, play, and customization of e-textiles and wearables without requiring the creation of code. This demo paper presents one such example of ongoing work: MakerShoe, an e-textile platform for designing shoe-based interactive wearable experiences. We discuss our two participatory design sessions as well as our initial prototype, which uses single-function magnetically attachable electronic modules to support circuit creation and the design of responsive, interactive behaviors.
# https://dl.acm.org/doi/10.1145/2493988.2494344
# We explore the wash-ability of conductive materials used in creating traces and touch sensors in wearable electronic textiles. We perform a wash test measuring change in resistivity after each of 10 cycles of washing for conductive traces constructed using two types of conductive thread, conductive ink, and combinations of thread and ink.
# https://dl.acm.org/doi/10.1145/3527927.3532809
#  Within the emerging field of e-textiles, goldwork embroidery (also known as metalwork) which uses metal threads and materials is an underexplored area, despite being a centuries-old practice in traditional crafts of different cultures. In this paper, we explore the material culture of textile goldwork to better understand how e-textile researchers can leverage their material properties, palette, and practices. First, we provide a historical background of English goldwork to give HCI researchers context on this craft field including technological and cultural influences. Then, we interview 13 contemporary goldwork practitioners on their creative practice to better understand the tools, techniques, and skills they employ. Our study findings show how goldwork practitioners deal with the unique constraints of metal threads and materials, and how these materials need to be handled differently than regular non-metal threads and fibers. This paper contributes an analysis of goldwork practices for HCI audiences with suggestions on how we can leverage these practices for the future of e-textile hybrid crafts.
# https://dl.acm.org/doi/10.1145/2037373.2037472
# As part of the EPSRC funded 'Digital Sensoria' project a set of digital tools were utilised to better demonstrate the tactile qualities of textiles via the internet. Shoogleit [8], an online utility for the creation of interactive video was one such tool. A Shoogle player for iOS mobile devices was then created (Orzechowski) using an iterative process, during which experiments were carried out to determine if the added interactivity afforded by Shoogleit could more accurately describe textile qualities and thus aid in the creation of a next generation mobile browser for textiles.

# %%
def convert_doi_to_acm_pdf_url(doi_url):
    """
    convert doi url to acm pdf url
    
    params:
    doi_url (str): original doi url, e.g. https://doi.org/10.1145/3316782.3316785
    
    returns:
    str: converted pdf url, e.g. https://dl.acm.org/doi/pdf/10.1145/3593856.3595907
    """
    acm_pdf_base_url = "https://dl.acm.org/doi/pdf/"
    doi_part = doi_url.split("https://doi.org/")[-1]
    acm_pdf_url = acm_pdf_base_url + doi_part
    
    return acm_pdf_url

# %%
# download pdf
full_abstract_file_path = './data/papers_data_with_full_abstract.json'


if os.path.exists(full_abstract_file_path):
    with open(full_abstract_file_path, 'r', encoding='utf-8') as file:
        papers_data = json.load(file)
    
    for paper in papers_data:
        pdflink = convert_doi_to_acm_pdf_url(paper["doi"])
        pdf_filename = paper["doi"].split('/')[-1] + '.pdf'
        save_path = os.path.join('pdf', pdf_filename)

        # check if the pdf file already exists
        if os.path.exists(save_path):
            print(f"{pdf_filename} already exists.")
            continue 

        print(f"Downloading {pdflink}...")

        # download pdf
        response = requests.get(pdflink)

        print(f"Status code: {response.status_code}")
        
        # make sure the response status code is 200
        if response.status_code == 200:
            # save the pdf file
            with open(save_path, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded {pdf_filename} successfully.")
        else:
            print(f"Failed to download {pdf_filename}. Status code: {response.status_code}")
        
        time.sleep(10)
# Out:
# 3316782.3316785.pdf already exists.
# 3123514.3123565.pdf already exists.
# 3084863.3084868.pdf already exists.
# 2556288.2557299.pdf already exists.
# 3170427.3188623.pdf already exists.
# 3305367.3327995.pdf already exists.
# 1858171.1858257.pdf already exists.
# 989863.989874.pdf already exists.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3306306.3338856...
# Status code: 200
# Downloaded 3306306.3338856.pdf successfully.
# 3406499.3418770.pdf already exists.
# 1178823.1178880.pdf already exists.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2641248.2666717...
# Status code: 200
# Downloaded 2641248.2666717.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/572020.572039...
# Status code: 200
# Downloaded 572020.572039.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3334480.3382788...
# Status code: 200
# Downloaded 3334480.3382788.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2893499...
# Status code: 200
# Downloaded 2893499.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2370216.2370348...
# Status code: 200
# Downloaded 2370216.2370348.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1709886.1709972...
# Status code: 200
# Downloaded 1709886.1709972.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3027063.3052972...
# Status code: 200
# Downloaded 3027063.3052972.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3472749.3474766...
# Status code: 200
# Downloaded 3472749.3474766.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3306346.3322988...
# Status code: 200
# Downloaded 3306346.3322988.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3357236.3395447...
# Status code: 200
# Downloaded 3357236.3395447.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3349263.3349598...
# Status code: 200
# Downloaded 3349263.3349598.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3446069...
# Status code: 200
# Downloaded 3430524.3446069.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2668956.2668959...
# Status code: 200
# Downloaded 2668956.2668959.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3332165.3347896...
# Status code: 200
# Downloaded 3332165.3347896.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3569551.3569557...
# Status code: 200
# Downloaded 3569551.3569557.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3282286.3282300...
# Status code: 200
# Downloaded 3282286.3282300.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3490149.3505577...
# Status code: 200
# Downloaded 3490149.3505577.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3559400.3562001...
# Status code: 200
# Downloaded 3559400.3562001.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3123021.3123058...
# Status code: 200
# Downloaded 3123021.3123058.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2069618.2069692...
# Status code: 200
# Downloaded 2069618.2069692.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1109/DATE.2005.138...
# Status code: 200
# Downloaded DATE.2005.138.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2641248.2641276...
# Status code: 200
# Downloaded 2641248.2641276.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544794.3560293...
# Status code: 200
# Downloaded 3544794.3560293.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544549.3582736...
# Status code: 200
# Downloaded 3544549.3582736.pdf successfully.
# 3544549.3582736.pdf already exists.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2968219.2979142...
# Status code: 200
# Downloaded 2968219.2979142.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544548.3581343...
# Status code: 200
# Downloaded 3544548.3581343.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2800835.2800936...
# Status code: 200
# Downloaded 2800835.2800936.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3526113.3545688...
# Status code: 200
# Downloaded 3526113.3545688.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2993148.2998520...
# Status code: 200
# Downloaded 2993148.2998520.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3126594.3126620...
# Status code: 200
# Downloaded 3126594.3126620.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3594739.3610717...
# Status code: 200
# Downloaded 3594739.3610717.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3173225.3173255...
# Status code: 200
# Downloaded 3173225.3173255.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3267242.3267281...
# Status code: 200
# Downloaded 3267242.3267281.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3064857.3079181...
# Status code: 200
# Downloaded 3064857.3079181.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3440642...
# Status code: 200
# Downloaded 3430524.3440642.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2493988.2494355...
# Status code: 200
# Downloaded 2493988.2494355.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2634317.2634326...
# Status code: 200
# Downloaded 2634317.2634326.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1935701.1935715...
# Status code: 200
# Downloaded 1935701.1935715.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2857546.2857621...
# Status code: 200
# Downloaded 2857546.2857621.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3563657.3596086...
# Status code: 200
# Downloaded 3563657.3596086.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544549.3583899...
# Status code: 200
# Downloaded 3544549.3583899.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3123024.3123151...
# Status code: 200
# Downloaded 3123024.3123151.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3440633...
# Status code: 200
# Downloaded 3430524.3440633.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3461778.3462139...
# Status code: 200
# Downloaded 3461778.3462139.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3419249.3420075...
# Status code: 200
# Downloaded 3419249.3420075.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3393914.3395840...
# Status code: 200
# Downloaded 3393914.3395840.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3569009.3572798...
# Status code: 200
# Downloaded 3569009.3572798.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2702613.2732739...
# Status code: 200
# Downloaded 2702613.2732739.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2634317.2634328...
# Status code: 200
# Downloaded 2634317.2634328.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3483529.3483742...
# Status code: 200
# Downloaded 3483529.3483742.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2641248.2641355...
# Status code: 200
# Downloaded 2641248.2641355.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2634317.2634331...
# Status code: 200
# Downloaded 2634317.2634331.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3123024.3123160...
# Status code: 200
# Downloaded 3123024.3123160.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3077981.3078043...
# Status code: 200
# Downloaded 3077981.3078043.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2702123.2702327...
# Status code: 200
# Downloaded 2702123.2702327.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3440630...
# Status code: 200
# Downloaded 3430524.3440630.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544548.3581295...
# Status code: 200
# Downloaded 3544548.3581295.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3313831.3376305...
# Status code: 200
# Downloaded 3313831.3376305.pdf successfully.
# 3332165.3347913.pdf already exists.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3611659.3616888...
# Status code: 200
# Downloaded 3611659.3616888.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3586183.3606815...
# Status code: 200
# Downloaded 3586183.3606815.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3446076...
# Status code: 200
# Downloaded 3430524.3446076.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3123021.3123057...
# Status code: 200
# Downloaded 3123021.3123057.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3341163.3347717...
# Status code: 200
# Downloaded 3341163.3347717.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2468356.2468643...
# Status code: 200
# Downloaded 2468356.2468643.pdf successfully.
# 3025453.3025938.pdf already exists.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3341162.3349572...
# Status code: 200
# Downloaded 3341162.3349572.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3429889.3429922...
# Status code: 200
# Downloaded 3429889.3429922.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3394981...
# Status code: 200
# Downloaded 3394981.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3491102.3502117...
# Status code: 200
# Downloaded 3491102.3502117.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3341162.3343817...
# Status code: 200
# Downloaded 3341162.3343817.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544548.3580920...
# Status code: 200
# Downloaded 3544548.3580920.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3586182.3615770...
# Status code: 200
# Downloaded 3586182.3615770.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3274783.3275178...
# Status code: 200
# Downloaded 3274783.3275178.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3213512.3213514...
# Status code: 200
# Downloaded 3213512.3213514.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3623509.3633351...
# Status code: 200
# Downloaded 3623509.3633351.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3490632.3490667...
# Status code: 200
# Downloaded 3490632.3490667.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3586183.3606764...
# Status code: 200
# Downloaded 3586183.3606764.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3594806.3594853...
# Status code: 200
# Downloaded 3594806.3594853.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3411763.3451824...
# Status code: 200
# Downloaded 3411763.3451824.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3313831.3376220...
# Status code: 200
# Downloaded 3313831.3376220.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3532106.3533535...
# Status code: 200
# Downloaded 3532106.3533535.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2494091.2494158...
# Status code: 200
# Downloaded 2494091.2494158.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3537797.3537880...
# Status code: 200
# Downloaded 3537797.3537880.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3313831.3376692...
# Status code: 200
# Downloaded 3313831.3376692.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3534522...
# Status code: 200
# Downloaded 3534522.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3594739.3610779...
# Status code: 200
# Downloaded 3594739.3610779.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3411764.3445155...
# Status code: 200
# Downloaded 3411764.3445155.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3623509.3633399...
# Status code: 200
# Downloaded 3623509.3633399.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3173225.3173341...
# Status code: 200
# Downloaded 3173225.3173341.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3586183.3606729...
# Status code: 200
# Downloaded 3586183.3606729.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3594739.3610692...
# Status code: 200
# Downloaded 3594739.3610692.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3569009.3572736...
# Status code: 200
# Downloaded 3569009.3572736.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3563703.3596638...
# Status code: 200
# Downloaded 3563703.3596638.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3640087.3640094...
# Status code: 200
# Downloaded 3640087.3640094.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2493988.2494337...
# Status code: 200
# Downloaded 2493988.2494337.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3532106.3533515...
# Status code: 200
# Downloaded 3532106.3533515.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3529190.3529215...
# Status code: 200
# Downloaded 3529190.3529215.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3495018.3495145...
# Status code: 200
# Downloaded 3495018.3495145.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3341163.3347739...
# Status code: 200
# Downloaded 3341163.3347739.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3334480.3383139...
# Status code: 200
# Downloaded 3334480.3383139.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3054953...
# Status code: 200
# Downloaded 3054953.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3388534.3407292...
# Status code: 200
# Downloaded 3388534.3407292.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2802083.2802093...
# Status code: 200
# Downloaded 2802083.2802093.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544548.3581156...
# Status code: 200
# Downloaded 3544548.3581156.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3460421.3480418...
# Status code: 200
# Downloaded 3460421.3480418.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3411764.3445712...
# Status code: 200
# Downloaded 3411764.3445712.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544549.3585873...
# Status code: 200
# Downloaded 3544549.3585873.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3419249.3421233...
# Status code: 200
# Downloaded 3419249.3421233.pdf successfully.
# 3544548.3581156.pdf already exists.
# 3460421.3480418.pdf already exists.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3527927.3531451...
# Status code: 200
# Downloaded 3527927.3531451.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3532106.3533488...
# Status code: 200
# Downloaded 3532106.3533488.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544794.3558475...
# Status code: 200
# Downloaded 3544794.3558475.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3313831.3376236...
# Status code: 200
# Downloaded 3313831.3376236.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2494091.2494143...
# Status code: 200
# Downloaded 2494091.2494143.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2384916.2384968...
# Status code: 200
# Downloaded 2384916.2384968.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3581961.3609842...
# Status code: 200
# Downloaded 3581961.3609842.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3620679.3620695...
# Status code: 200
# Downloaded 3620679.3620695.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3442451...
# Status code: 200
# Downloaded 3430524.3442451.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544548.3581288...
# Status code: 200
# Downloaded 3544548.3581288.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3623509.3633374...
# Status code: 200
# Downloaded 3623509.3633374.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2093698.2093827...
# Status code: 200
# Downloaded 2093698.2093827.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3313991.3314000...
# Status code: 200
# Downloaded 3313991.3314000.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2971763.2971785...
# Status code: 200
# Downloaded 2971763.2971785.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3567445.3567455...
# Status code: 200
# Downloaded 3567445.3567455.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2967175.2967384...
# Status code: 200
# Downloaded 2967175.2967384.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3526113.3545694...
# Status code: 200
# Downloaded 3526113.3545694.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3513023...
# Status code: 200
# Downloaded 3513023.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2971648.2971695...
# Status code: 200
# Downloaded 2971648.2971695.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3544548.3580769...
# Status code: 200
# Downloaded 3544548.3580769.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3386201.3386217...
# Status code: 200
# Downloaded 3386201.3386217.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3266037.3271647...
# Status code: 200
# Downloaded 3266037.3271647.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3460418.3479347...
# Status code: 200
# Downloaded 3460418.3479347.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3284432.3284449...
# Status code: 200
# Downloaded 3284432.3284449.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3267305.3267644...
# Status code: 200
# Downloaded 3267305.3267644.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3472749.3474802...
# Status code: 200
# Downloaded 3472749.3474802.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3507959.3507962...
# Status code: 200
# Downloaded 3507959.3507962.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3495018.3495144...
# Status code: 200
# Downloaded 3495018.3495144.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3563657.3595988...
# Status code: 200
# Downloaded 3563657.3595988.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3440657...
# Status code: 200
# Downloaded 3430524.3440657.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3594739.3610785...
# Status code: 200
# Downloaded 3594739.3610785.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3569009.3572734...
# Status code: 200
# Downloaded 3569009.3572734.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3197391.3205389...
# Status code: 200
# Downloaded 3197391.3205389.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3012430.3012493...
# Status code: 200
# Downloaded 3012430.3012493.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3173225.3173293...
# Status code: 200
# Downloaded 3173225.3173293.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1935701.1935765...
# Status code: 200
# Downloaded 1935701.1935765.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2460625.2460640...
# Status code: 200
# Downloaded 2460625.2460640.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1279740.1279746...
# Status code: 200
# Downloaded 1279740.1279746.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2047196.2047235...
# Status code: 200
# Downloaded 2047196.2047235.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1520340.1520542...
# Status code: 200
# Downloaded 1520340.1520542.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3202185.3210770...
# Status code: 200
# Downloaded 3202185.3210770.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2851581.2892529...
# Status code: 200
# Downloaded 2851581.2892529.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2851581.2889466...
# Status code: 200
# Downloaded 2851581.2889466.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2677199.2690871...
# Status code: 200
# Downloaded 2677199.2690871.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3393914.3395843...
# Status code: 200
# Downloaded 3393914.3395843.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3341162.3343846...
# Status code: 200
# Downloaded 3341162.3343846.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3131785.3131797...
# Status code: 200
# Downloaded 3131785.3131797.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2858036.2858544...
# Status code: 200
# Downloaded 2858036.2858544.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3213818.3219812...
# Status code: 200
# Downloaded 3213818.3219812.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3294109.3300973...
# Status code: 200
# Downloaded 3294109.3300973.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3027063.3053104...
# Status code: 200
# Downloaded 3027063.3053104.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2971763.2971786...
# Status code: 200
# Downloaded 2971763.2971786.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1056808.1056949...
# Status code: 200
# Downloaded 1056808.1056949.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3242969.3242977...
# Status code: 200
# Downloaded 3242969.3242977.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1978942.1979380...
# Status code: 200
# Downloaded 1978942.1979380.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2069618.2069698...
# Status code: 200
# Downloaded 2069618.2069698.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2181037.2181096...
# Status code: 200
# Downloaded 2181037.2181096.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1052380.1052381...
# Status code: 200
# Downloaded 1052380.1052381.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3242969.3264968...
# Status code: 200
# Downloaded 3242969.3264968.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3379337.3415876...
# Status code: 200
# Downloaded 3379337.3415876.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2638728.2638746...
# Status code: 200
# Downloaded 2638728.2638746.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3003397.3003410...
# Status code: 200
# Downloaded 3003397.3003410.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.4108/icst.pervasivehealth.2013.252104...
# Status code: 200
# Downloaded icst.pervasivehealth.2013.252104.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2984511.2984572...
# Status code: 200
# Downloaded 2984511.2984572.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3430524.3444700...
# Status code: 200
# Downloaded 3430524.3444700.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3379337.3415886...
# Status code: 200
# Downloaded 3379337.3415886.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3173225.3173245...
# Status code: 200
# Downloaded 3173225.3173245.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2494091.2494157...
# Status code: 200
# Downloaded 2494091.2494157.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3012709.3018008...
# Status code: 200
# Downloaded 3012709.3018008.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3159450.3162360...
# Status code: 200
# Downloaded 3159450.3162360.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3332165.3347882...
# Status code: 200
# Downloaded 3332165.3347882.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3132272.3134128...
# Status code: 200
# Downloaded 3132272.3134128.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3328778.3372713...
# Status code: 200
# Downloaded 3328778.3372713.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3410531.3414305...
# Status code: 200
# Downloaded 3410531.3414305.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3325480.3329176...
# Status code: 200
# Downloaded 3325480.3329176.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3328243.3328267...
# Status code: 200
# Downloaded 3328243.3328267.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3328778.3372712...
# Status code: 200
# Downloaded 3328778.3372712.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2677199.2680560...
# Status code: 200
# Downloaded 2677199.2680560.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1810543.1810567...
# Status code: 200
# Downloaded 1810543.1810567.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2757226.2757231...
# Status code: 200
# Downloaded 2757226.2757231.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3341162.3343775...
# Status code: 200
# Downloaded 3341162.3343775.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1810543.1810574...
# Status code: 200
# Downloaded 1810543.1810574.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2148131.2148233...
# Status code: 200
# Downloaded 2148131.2148233.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/1979742.1979707...
# Status code: 200
# Downloaded 1979742.1979707.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3580883...
# Status code: 200
# Downloaded 3580883.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3123021.3123068...
# Status code: 200
# Downloaded 3123021.3123068.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3242587.3242664...
# Status code: 200
# Downloaded 3242587.3242664.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2512349.2512813...
# Status code: 200
# Downloaded 2512349.2512813.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3197391.3205382...
# Status code: 200
# Downloaded 3197391.3205382.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2971763.2971784...
# Status code: 200
# Downloaded 2971763.2971784.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2800835.2807931...
# Status code: 200
# Downloaded 2800835.2807931.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3290607.3312857...
# Status code: 200
# Downloaded 3290607.3312857.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2700648.2811355...
# Status code: 200
# Downloaded 2700648.2811355.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2347504.2347542...
# Status code: 200
# Downloaded 2347504.2347542.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3610927...
# Status code: 200
# Downloaded 3610927.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2771839.2771883...
# Status code: 200
# Downloaded 2771839.2771883.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2493988.2494344...
# Status code: 200
# Downloaded 2493988.2494344.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/3527927.3532809...
# Status code: 200
# Downloaded 3527927.3532809.pdf successfully.
# Downloading https://dl.acm.org/doi/pdf/10.1145/2037373.2037472...
# Status code: 200
# Downloaded 2037373.2037472.pdf successfully.

# %%
# fetch image from pdf
import fitz  # PyMuPDF

def extract_first_image_from_pdf(pdf_path, image_save_path):
    """
    Extract the first image from a PDF file that meets size criteria and save it to a file.
    If the image is smaller than 20KB or exactly 51KB, it skips to the next available image.
    
    Params:
    pdf_path (str): Path to the PDF file.
    image_save_path (str): Path to save the extracted image.
    """
    doc = fitz.open(pdf_path)
    
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        image_list = page.get_images(full=True)
        
        for image_index, img in enumerate(image_list):
            xref = img[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            
            # Check the size of the image
            if len(image_bytes) < 61200:  # Image is smaller than 20KB or exactly 51KB
                continue  # Skip to the next image
            else:
                # Save the image that meets the criteria
                with open(image_save_path, "wb") as img_file:
                    img_file.write(image_bytes)
                print(f"Image extracted and saved to {image_save_path}")
                return  # Image saved, no need to continue with this PDF
                
    doc.close()
    print(f"No suitable image found in {pdf_path}")


full_abstract_file_path = './data/papers_data_with_full_abstract.json'

no_image_list = []

if os.path.exists(full_abstract_file_path):
    with open(full_abstract_file_path, 'r', encoding='utf-8') as file:
        papers_data = json.load(file)
    
    for paper in papers_data:
        try: 
            pdf_path = "./pdf/"+paper["doi"].split('/')[-1] + '.pdf'
            image_save_path = "./image/"+paper["doi"].split('/')[-1]+".png"
            extract_first_image_from_pdf(pdf_path, image_save_path)
        except:
            no_image_list.append(paper["doi"])
            print(f"No image found in {pdf_path}")
            continue
# Out:
# Image extracted and saved to ./image/3316782.3316785.png
# Image extracted and saved to ./image/3123514.3123565.png
# Image extracted and saved to ./image/3084863.3084868.png
# Image extracted and saved to ./image/2556288.2557299.png
# Image extracted and saved to ./image/3170427.3188623.png
# Image extracted and saved to ./image/3305367.3327995.png
# Image extracted and saved to ./image/1858171.1858257.png
# No suitable image found in ./pdf/989863.989874.pdf
# No image found in ./pdf/3306306.3338856.pdf
# Image extracted and saved to ./image/3406499.3418770.png
# No suitable image found in ./pdf/1178823.1178880.pdf
# Image extracted and saved to ./image/2641248.2666717.png
# Image extracted and saved to ./image/572020.572039.png
# Image extracted and saved to ./image/3334480.3382788.png
# Image extracted and saved to ./image/2893499.png
# No suitable image found in ./pdf/2370216.2370348.pdf
# Image extracted and saved to ./image/1709886.1709972.png
# Image extracted and saved to ./image/3027063.3052972.png
# Image extracted and saved to ./image/3472749.3474766.png
# Image extracted and saved to ./image/3306346.3322988.png
# Image extracted and saved to ./image/3357236.3395447.png
# Image extracted and saved to ./image/3349263.3349598.png
# Image extracted and saved to ./image/3430524.3446069.png
# Image extracted and saved to ./image/2668956.2668959.png
# Image extracted and saved to ./image/3332165.3347896.png
# No suitable image found in ./pdf/3569551.3569557.pdf
# Image extracted and saved to ./image/3282286.3282300.png
# Image extracted and saved to ./image/3490149.3505577.png
# Image extracted and saved to ./image/3559400.3562001.png
# Image extracted and saved to ./image/3123021.3123058.png
# No suitable image found in ./pdf/2069618.2069692.pdf
# No suitable image found in ./pdf/DATE.2005.138.pdf
# Image extracted and saved to ./image/2641248.2641276.png
# Image extracted and saved to ./image/3544794.3560293.png
# Image extracted and saved to ./image/3544549.3582736.png
# Image extracted and saved to ./image/3544549.3582736.png
# No suitable image found in ./pdf/2968219.2979142.pdf
# Image extracted and saved to ./image/3544548.3581343.png
# Image extracted and saved to ./image/2800835.2800936.png
# Image extracted and saved to ./image/3526113.3545688.png
# No suitable image found in ./pdf/2993148.2998520.pdf
# Image extracted and saved to ./image/3126594.3126620.png
# Image extracted and saved to ./image/3594739.3610717.png
# Image extracted and saved to ./image/3173225.3173255.png
# Image extracted and saved to ./image/3267242.3267281.png
# Image extracted and saved to ./image/3064857.3079181.png
# Image extracted and saved to ./image/3430524.3440642.png
# Image extracted and saved to ./image/2493988.2494355.png
# Image extracted and saved to ./image/2634317.2634326.png
# Image extracted and saved to ./image/1935701.1935715.png
# No suitable image found in ./pdf/2857546.2857621.pdf
# Image extracted and saved to ./image/3563657.3596086.png
# Image extracted and saved to ./image/3544549.3583899.png
# Image extracted and saved to ./image/3123024.3123151.png
# Image extracted and saved to ./image/3430524.3440633.png
# Image extracted and saved to ./image/3461778.3462139.png
# Image extracted and saved to ./image/3419249.3420075.png
# Image extracted and saved to ./image/3393914.3395840.png
# Image extracted and saved to ./image/3569009.3572798.png
# Image extracted and saved to ./image/2702613.2732739.png
# Image extracted and saved to ./image/2634317.2634328.png
# Image extracted and saved to ./image/3483529.3483742.png
# No suitable image found in ./pdf/2641248.2641355.pdf
# Image extracted and saved to ./image/2634317.2634331.png
# Image extracted and saved to ./image/3123024.3123160.png
# Image extracted and saved to ./image/3077981.3078043.png
# Image extracted and saved to ./image/2702123.2702327.png
# Image extracted and saved to ./image/3430524.3440630.png
# Image extracted and saved to ./image/3544548.3581295.png
# Image extracted and saved to ./image/3313831.3376305.png
# Image extracted and saved to ./image/3332165.3347913.png
# Image extracted and saved to ./image/3611659.3616888.png
# Image extracted and saved to ./image/3586183.3606815.png
# Image extracted and saved to ./image/3430524.3446076.png
# Image extracted and saved to ./image/3123021.3123057.png
# No suitable image found in ./pdf/3341163.3347717.pdf
# Image extracted and saved to ./image/2468356.2468643.png
# Image extracted and saved to ./image/3025453.3025938.png
# No suitable image found in ./pdf/3341162.3349572.pdf
# Image extracted and saved to ./image/3429889.3429922.png
# Image extracted and saved to ./image/3394981.png
# Image extracted and saved to ./image/3491102.3502117.png
# Image extracted and saved to ./image/3341162.3343817.png
# Image extracted and saved to ./image/3544548.3580920.png
# Image extracted and saved to ./image/3586182.3615770.png
# No suitable image found in ./pdf/3274783.3275178.pdf
# Image extracted and saved to ./image/3213512.3213514.png
# Image extracted and saved to ./image/3623509.3633351.png
# Image extracted and saved to ./image/3490632.3490667.png
# Image extracted and saved to ./image/3586183.3606764.png
# Image extracted and saved to ./image/3594806.3594853.png
# Image extracted and saved to ./image/3411763.3451824.png
# Image extracted and saved to ./image/3313831.3376220.png
# Image extracted and saved to ./image/3532106.3533535.png
# Image extracted and saved to ./image/2494091.2494158.png
# No suitable image found in ./pdf/3537797.3537880.pdf
# Image extracted and saved to ./image/3313831.3376692.png
# Image extracted and saved to ./image/3534522.png
# Image extracted and saved to ./image/3594739.3610779.png
# Image extracted and saved to ./image/3411764.3445155.png
# Image extracted and saved to ./image/3623509.3633399.png
# No suitable image found in ./pdf/3173225.3173341.pdf
# Image extracted and saved to ./image/3586183.3606729.png
# Image extracted and saved to ./image/3594739.3610692.png
# Image extracted and saved to ./image/3569009.3572736.png
# Image extracted and saved to ./image/3563703.3596638.png
# Image extracted and saved to ./image/3640087.3640094.png
# No suitable image found in ./pdf/2493988.2494337.pdf
# Image extracted and saved to ./image/3532106.3533515.png
# Image extracted and saved to ./image/3529190.3529215.png
# Image extracted and saved to ./image/3495018.3495145.png
# Image extracted and saved to ./image/3341163.3347739.png
# Image extracted and saved to ./image/3334480.3383139.png
# Image extracted and saved to ./image/3054953.png
# Image extracted and saved to ./image/3388534.3407292.png
# Image extracted and saved to ./image/2802083.2802093.png
# Image extracted and saved to ./image/3544548.3581156.png
# Image extracted and saved to ./image/3460421.3480418.png
# Image extracted and saved to ./image/3411764.3445712.png
# Image extracted and saved to ./image/3544549.3585873.png
# Image extracted and saved to ./image/3419249.3421233.png
# Image extracted and saved to ./image/3544548.3581156.png
# Image extracted and saved to ./image/3460421.3480418.png
# Image extracted and saved to ./image/3527927.3531451.png
# Image extracted and saved to ./image/3532106.3533488.png
# No suitable image found in ./pdf/3544794.3558475.pdf
# Image extracted and saved to ./image/3313831.3376236.png
# Image extracted and saved to ./image/2494091.2494143.png
# No suitable image found in ./pdf/2384916.2384968.pdf
# Image extracted and saved to ./image/3581961.3609842.png
# No suitable image found in ./pdf/3620679.3620695.pdf
# Image extracted and saved to ./image/3430524.3442451.png
# Image extracted and saved to ./image/3544548.3581288.png
# Image extracted and saved to ./image/3623509.3633374.png
# Image extracted and saved to ./image/2093698.2093827.png
# Image extracted and saved to ./image/3313991.3314000.png
# Image extracted and saved to ./image/2971763.2971785.png
# Image extracted and saved to ./image/3567445.3567455.png
# Image extracted and saved to ./image/2967175.2967384.png
# Image extracted and saved to ./image/3526113.3545694.png
# Image extracted and saved to ./image/3513023.png
# Image extracted and saved to ./image/2971648.2971695.png
# Image extracted and saved to ./image/3544548.3580769.png
# Image extracted and saved to ./image/3386201.3386217.png
# Image extracted and saved to ./image/3266037.3271647.png
# Image extracted and saved to ./image/3460418.3479347.png
# No suitable image found in ./pdf/3284432.3284449.pdf
# Image extracted and saved to ./image/3267305.3267644.png
# Image extracted and saved to ./image/3472749.3474802.png
# Image extracted and saved to ./image/3507959.3507962.png
# Image extracted and saved to ./image/3495018.3495144.png
# Image extracted and saved to ./image/3563657.3595988.png
# Image extracted and saved to ./image/3430524.3440657.png
# Image extracted and saved to ./image/3594739.3610785.png
# Image extracted and saved to ./image/3569009.3572734.png
# Image extracted and saved to ./image/3197391.3205389.png
# Image extracted and saved to ./image/3012430.3012493.png
# Image extracted and saved to ./image/3173225.3173293.png
# No suitable image found in ./pdf/1935701.1935765.pdf
# Image extracted and saved to ./image/2460625.2460640.png
# No suitable image found in ./pdf/1279740.1279746.pdf
# Image extracted and saved to ./image/2047196.2047235.png
# Image extracted and saved to ./image/1520340.1520542.png
# No suitable image found in ./pdf/3202185.3210770.pdf
# Image extracted and saved to ./image/2851581.2892529.png
# Image extracted and saved to ./image/2851581.2889466.png
# Image extracted and saved to ./image/2677199.2690871.png
# Image extracted and saved to ./image/3393914.3395843.png
# Image extracted and saved to ./image/3341162.3343846.png
# Image extracted and saved to ./image/3131785.3131797.png
# Image extracted and saved to ./image/2858036.2858544.png
# Image extracted and saved to ./image/3213818.3219812.png
# Image extracted and saved to ./image/3294109.3300973.png
# Image extracted and saved to ./image/3027063.3053104.png
# Image extracted and saved to ./image/2971763.2971786.png
# Image extracted and saved to ./image/1056808.1056949.png
# Image extracted and saved to ./image/3242969.3242977.png
# Image extracted and saved to ./image/1978942.1979380.png
# Image extracted and saved to ./image/2069618.2069698.png
# No suitable image found in ./pdf/2181037.2181096.pdf
# No suitable image found in ./pdf/1052380.1052381.pdf
# Image extracted and saved to ./image/3242969.3264968.png
# Image extracted and saved to ./image/3379337.3415876.png
# Image extracted and saved to ./image/2638728.2638746.png
# Image extracted and saved to ./image/3003397.3003410.png
# Image extracted and saved to ./image/icst.pervasivehealth.2013.252104.png
# Image extracted and saved to ./image/2984511.2984572.png
# Image extracted and saved to ./image/3430524.3444700.png
# Image extracted and saved to ./image/3379337.3415886.png
# No suitable image found in ./pdf/3173225.3173245.pdf
# Image extracted and saved to ./image/2494091.2494157.png
# Image extracted and saved to ./image/3012709.3018008.png
# No image found in ./pdf/3159450.3162360.pdf
# Image extracted and saved to ./image/3332165.3347882.png
# Image extracted and saved to ./image/3132272.3134128.png
# No image found in ./pdf/3328778.3372713.pdf
# Image extracted and saved to ./image/3410531.3414305.png
# Image extracted and saved to ./image/3325480.3329176.png
# No suitable image found in ./pdf/3328243.3328267.pdf
# No image found in ./pdf/3328778.3372712.pdf
# Image extracted and saved to ./image/2677199.2680560.png
# Image extracted and saved to ./image/1810543.1810567.png
# No suitable image found in ./pdf/2757226.2757231.pdf
# Image extracted and saved to ./image/3341162.3343775.png
# Image extracted and saved to ./image/1810543.1810574.png
# Image extracted and saved to ./image/2148131.2148233.png
# Image extracted and saved to ./image/1979742.1979707.png
# Image extracted and saved to ./image/3580883.png
# Image extracted and saved to ./image/3123021.3123068.png
# Image extracted and saved to ./image/3242587.3242664.png
# Image extracted and saved to ./image/2512349.2512813.png
# Image extracted and saved to ./image/3197391.3205382.png
# Image extracted and saved to ./image/2971763.2971784.png
# No suitable image found in ./pdf/2800835.2807931.pdf
# Image extracted and saved to ./image/3290607.3312857.png
# No suitable image found in ./pdf/2700648.2811355.pdf
# No suitable image found in ./pdf/2347504.2347542.pdf
# No suitable image found in ./pdf/3610927.pdf
# Image extracted and saved to ./image/2771839.2771883.png
# No suitable image found in ./pdf/2493988.2494344.pdf
# Image extracted and saved to ./image/3527927.3532809.png
# No suitable image found in ./pdf/2037373.2037472.pdf

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai

genai.configure(api_key="AIzaSyD9pgMYx4gTkWZrTWxaWK4LMqTh6P6F0Z0")

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

# %%
prompt_start = """Based on the abstract below, extract keywords of the paper."""

prompt_end = """Notice, I will extract a lot of similar papers all about textiles, so I need to extract the most specific keywords possible. For example, I am interested in how they made the smart textiles (embroidered) and what they did with the smart textiles (sensing, actuating, and connecting components, etc.), not something like “textiles” or “smart textile”. The ones he extracted are meaningless because all the articles I collected are about textiles. I want more specific keywords with a specific purpose.
    dimensions include: 
    1. method that they used to fabricate textiles (e.g. coating, In-situ polymerization, etc.)
    2. tools used (e.g. embroidery machine, knitting machine, punch needle, etc.) 
    3. materials used (conductive thread, carbon ink, PPy, etc.) 
    4. what they did with the textiles (use textiles to do what? sensing? displaying? output, actuating?, applications, etc.) 
    5. if they conduct any workshop or user study (if yes, return "user study") 
    6. special techniques used (e.g. self-powered, TENG, piezoresistivity, etc.)
    for each dimensions, if the outlines are not applicable, e.g. in the abstract they did not describe how they made the textiles, return NA for that dimension.
    Organize the output keywords as a python list, e.g. [“sensing”, “displaying”, “embroidery machine”, “conductive thread”, “user study”] 
    In the output, remove NA, and you can have multiple keywords (but no more than 3) for each dimension.
    """
# types of smart textiles (sensing, output, actuating, displaying, etc.)

abstract1 = """
    "Interactive interiors which are customizable to the design preferences and functional purposes of individual users can help create flexible interiors within fixed spaces. They are particularly relevant to densely populated cities where most people live in compact spaces. This proposed research explores interactive interior textile surfaces as an adaptive media which can transform interiors via the change of colors, luminescence and surface design. This is done by investigating the integration of textile base material via embellishment techniques, such as embroidery and felting, with polymeric photonic fibers (POF) which enhance tactile quality without compromising on the technological functionality. Their flexible application methods mean that, it is adaptable to the rigid nature of polymeric photonic fibers. In addition, embroidery has the unique ability to arrange and combine threads together with various materials in non-rigid formations and multiple directions to create stable two-dimensional and three-dimensional forms [1]. Different materials can be combined to explore aesthetically pleasing surface designs, textures and achieve positive tactile quality.",
    """

response = model.generate_content(prompt_start+abstract1+prompt_end)
print(response.text)
# keyword = json.loads(response.text)
# Out:
# ["embroidery", "felting", "polymeric photonic fibers (POF)"]

# %%
# generate keywords
full_abstract_file_path = './data/papers_data_with_full_abstract.json'
keywords_file_path = './data/papers_data_with_keywords.json'

if os.path.exists(full_abstract_file_path):
    with open(full_abstract_file_path, 'r', encoding='utf-8') as file:
        papers_data = json.load(file)
    
    # generate keywords for each paper
    for paper in papers_data:
        abstract = paper.get('abstract_full', '')
        
        try:
            response = model.generate_content(prompt_start+abstract+prompt_end)
            print(response.text)
            keywords = json.loads(response.text.replace("```python\n", "").replace("\n```", ""))
        except Exception as e:
            try:
                print(f"Error generating keywords for {paper['doi']}: {e}")
                keywords = response.text
            except:
                keywords = ""

        paper['keywords'] = keywords  # add the keywords to the paper data
        time.sleep(1)
        
    # save the updated data to a new file
    with open(keywords_file_path, 'w', encoding='utf-8') as new_file:
        json.dump(papers_data, new_file, indent=4)
# Out:
# ["capacitive proximity sensors", "embroidery machine", "posture tracking", "user feedback", "user study"]
# ["sensing", "embroidery machine", "conductive thread"]
# ["touch-sensitive", "XY coordinate position", "pressure", "flexible", "lightweight", "low cost", "cuff-based user interface", "jacket"]
# , 4. 冢.
# Error generating keywords for https://doi.org/10.1145/2556288.2557299: Expecting value: line 1 column 1 (char 0)
# ["persuasive game", "textile production", "environmental impact", "societal concerns", "labour rights", "sustainable practices", "Textile Manager", "expert interviews", "pre-post exposure study", "persuasive effect", "voluntary information quests", "visualization of consequences"]
# [“shape and structure change”, “heat”, “sizing customization”, “aesthetic patterning”, “embroidery machine”]
# Error generating keywords for https://doi.org/10.1145/3305367.3327995: Expecting value: line 1 column 2 (char 1)
# ["handcrafting", "sensor", "circuitry", "electronic textile materials", "user study"]
# ["focus-plus-context", "window management", "spatial memory", "task switching", "user study"]
# ["3D printing", "Cosplay", "Fashion"]
# ["programmable drawing robots", "collective", "interactive", "co-crafting", "man-machine interaction"]
# ["non-emissive", "color-changing textiles", "liquid crystal ink", "ambient display", "fabrics", "fashion", "interior decoration"]
# ["textile composites", "conductive threads", "textile circuits"]
# - method that they used to fabricate the smart textiles: In-textile polymerization
# - tools used: N/A
# - materials used: PPy
# - what they did with the smart textiles: sensing
# - if they conduct any user study: N/A
# - special techniques used: N/A
# Error generating keywords for https://doi.org/10.1145/572020.572039: Expecting value: line 1 column 1 (char 0)
# ["3D printing", "water-responsive", "reversible actuation", "actuator design space"]
# ["3D printing", "fabric", "flexible", "deformable", "sensors", "actuators"]
# ["stitched", "multi-layer circuit creation", "accessible tools and techniques"]
# Error generating keywords for https://doi.org/10.1145/1709886.1709972: The `response.text` quick accessor only works for simple (single-`Part`) text responses. This response is not simple text.Use the `result.parts` accessor or the full `result.candidates[index].content.parts` lookup instead.
# ["needlecraft tools", "electric engineering", "information about electric properties", "user study"]
# [“displaying”, “LED matrix”, “bright LED”, “low resolution”, “user study”]
# Error generating keywords for https://doi.org/10.1145/3472749.3474766: Expecting value: line 1 column 2 (char 1)
# ["fabric formwork", "flat panels", "force equilibrium", "liquid fill", "tension", "external supports", "target shape"]
# ["alternative presents", "autobiographical design", "RtD", "speculative design", "dynamic fabric", "lived experience", "social-technical aspects"]
# ["visual feedforward", "shape-changing feedforward", "embroidery machine", "textile-based HMI", "user study"]
# , 1) 2) 3) 4) 5) 6)
# Error generating keywords for https://doi.org/10.1145/3430524.3446069: Expecting value: line 1 column 1 (char 0)
# ["multi-scale texture samples", "multi-touch gesture interface", "3D texture generation", "3D draping", "collision detection methods"]
# ["Fused deposition modeling (FDM)", "3D printing", "Weaving", "Conductive filament", "Interactive object", "Custom object design"]
# - for each dimension, we have a list of all the data that we use to make a list of the for this, that they used to find a with that they have, to use the
# Error generating keywords for https://doi.org/10.1145/3569551.3569557: Expecting value: line 1 column 1 (char 0)
# ["fabric defect detection", "deep learning", "Single Shot Multibox Detector", "SSD"]
# ["3D printing", "conductive sequins", "traditional sequin embroidery", "sensing"]
# ["3D printing", "plastic-on-top-of-fabric strips", "Saint-Venant–Kirchhoff material law", "stretchy fabric"]
# [“stitched”, “surface-mount components”, “solder deposition technique”, “LED matrix display”]
# Error generating keywords for https://doi.org/10.1145/3123021.3123058: Expecting value: line 1 column 2 (char 1)
# ["interpretative flexibility", "LilyPad Arduino", "e-textiles", "remixes", "user study"]
# ["energy-aware routing", "e-textile platforms", "low-power techniques", "Advanced Encryption Standard (AES) cipher"]
# [“E-Textiles”, “physical work samples”, “physicality”, “quality workmanship”]
# Error generating keywords for https://doi.org/10.1145/2641248.2641276: Expecting value: line 1 column 2 (char 1)
# ["temperature sensing", "flexible interposers", "modular design", "stress testing", "skin temperature"]
# ["motion-capture sensors", "robotic arms", "movement translation", "body-textile hybrids", "intra-action theory"]
# ["motion-capture sensors", "robotic arms", "movement translation", "body-textile hybrids", "intra-action theory"]
# - sensing
# - actuating
# - Textile Thinking
# - Ultra Personalization
# - Fit
# - interaction design
# - near field
# Error generating keywords for https://doi.org/10.1145/2968219.2979142: Expecting value: line 1 column 1 (char 0)
# ```python
# ["machine-knitting", "small-scale actuators", "fiber-like actuators", "compression", "edema mobilization", "user study"]
# ```
# ["two-warp system", "surface mounted components", "insulated threads", "magnetic field detection"]
# ["3D printing", "2.5D smart conductive sequin textile", "motion sensing", "posture detection", "user study"]
# ["deformable screen", "depth perception", "video conferencing"]
# [“data storage”, “interaction”, “magnetization”, “conductive thread”, “magnetometer”, “gesture recognition”, “fashion accessories”]
# Error generating keywords for https://doi.org/10.1145/3126594.3126620: Expecting value: line 1 column 2 (char 1)
# ["keypad matrix", "e-textile", "digitizing", "fabric draping", "3D rendering"]
# ["electronic textiles", "eTextiles", "wearables", "interior design", "education", "maker cultures", "specialized tools", "electronic textile making", "prototypes", "use cases", "new practices", "understanding of the discipline"]
# ["EMG", "e-textile headband", "motion artifacts"]
# ["thermohaptic feedback", "industrially knitted fabric", "ambient notification devices"]
# ["rapid prototyping", "e-textile prototyping", "ThreadBoard"]
# ["resistance", "conductive yarn", "coverstitch machine", "quasi-binary resistance response", "linear response", "self-intersecting folds", "non-contact bends", "robotic mannequin", "human"]
# ["sensing", "stretch sensor", "bend sensor", "e-textile", "washable sensor", "insulating film", "fusible polymer film"]
# ["textile sensors", "embroidery", "conductive thread", "sensing", "website", "workshops", "user study"]
# ["RFID", "Kevlar substrate", "CST Microwave Studio"]
# ["multi-layer weaving", "conductive yarn", "electronic sensing", "paper prototyping tool"]
# ,tse.
# Error generating keywords for https://doi.org/10.1145/3544549.3583899: Expecting value: line 1 column 1 (char 0)
# ["sensing", "embroidery machine", "conductive thread"]
# ["shape changing fabric", "embroidery machine", "user study"]
# ["design", "fabrication", "sensing", "visual affordances", "perception of textures", "direction of movement", "economic usage of design elements"]
# ,
# Error generating keywords for https://doi.org/10.1145/3419249.3420075: Expecting value: line 1 column 1 (char 0)
# ["traditional handcrafts", "digital technologies", "chemical processes", "nature", "haptic interactions", "acoustic soundscapes"]
# ["optical sensing", "woven", "carboxymethyl cellulose (CMC) optical waveguides", "double-diamond methodology", "practice-based design research", "empirical material science"]
# ["transforming textural expressions", "computational textiles", "electronic commands", "aesthetic textural expression"]
# ["active capacitive sensing", "head gesture recognition", "head posture recognition", "neckband", "capacitive electrodes", "textile", "hands-free control interfaces", "electric wheelchair", "motor impairments"]
# ["sensing", "embroidery machine", "user study"]
# ["reconfigurable smart garment", "swatches", "customization", "mobility", "ergonomics comfort", "ease of use", "optimal data flow"]
# - Fabrication method: NA
# - Tools: NA
# - Materials: NA
# - Applications: posture instruction, prevent caregiver's injury in health and medical care
# - Special techniques: NA
# Error generating keywords for https://doi.org/10.1145/2634317.2634331: Expecting value: line 1 column 1 (char 0)
# ```python
# ["Liberator40® conductive fiber", "serpentine pattern", "stretch knit fabrics", "temperature output"]
# ```
# ["knitting", "machine knitting", "hand knitting", "conductive polymer", "stretching", "releasing"]
# ```python
# ["laser cutter", "heat sensitive adhesive", "conductive fabric", "touch sensing", "LED display", "wireless power reception"]
# ```
# ["embroidery", "e-textiles", "audio speakers", "vibro-haptic actuators", "user study"]
# ["capacitive sensing", "wearable affective display", "machine learning", "personalized classifier", "LiveEmoji applications", "online communication", "face-to-face communication", "user interviews", "user study"]
# ["embroidery machine", "resistive textiles", "conductive yarns", "force sensitive resistors", "sensing"]
# ["wireless sensor nodes", "fabric snap fasteners", "inertial measurement units", "gestural interfaces", "music player controller", "cursor control", "motion tracking suit", "user study"]
# ["EMG", "GSR", "Virtual Reality (VR)", "physiological measures", "emotion", "cognitive load", "facial expressions"]
# ["embroidery", "machine embroidery", "sensing", "actuating", "connecting", "visual programming", "user study"]
# ["interactive books", "eTextile", "handmade interactive textile book", "interactive qualities", "materials used", "story experience", "tangible, embedded, and embodied interactions"]
# ["wetness detection", "conductive thread", "saline", "copper filament", "silver threads", "bi-metallic sensor"]
# ["stitched", "knit fabrics", "cyclic extension", "elastic modulus", "chainstitch sensor", "coverstitch sensor"]
# 1. Fabrication method: N/A
# 2. Tools used: N/A
# 3. Materials used: Thermochromatic inks, peltier semiconductors
# 4. Applications: Touch-sensitive non-light-emissive display
# 5. User study: N/A
# 6. Special techniques: Temperature transients detection
# Error generating keywords for https://doi.org/10.1145/2468356.2468643: Extra data: line 1 column 2 (char 1)
# ["stitch-based", "embroidery", "conductive yarns", "stretch sensors", "eyes-free interactions", "causal interactions", "StretchEBand", "user study"]
# ["sensing", "menstrual blood loss volume", "embroidery machine"]
# ["droplet jet technology", "chemical deposition technology", "conductive layer", "fabric electrode", "ECG signal", "silver particles", "AC impedance", "Ag-AgCl electrode", "plain weave fabric electrode", "gel Ag-AgCl electrode"]
# ["capacitive touch sensing", "knitting", "conductive yarn", "Bode analysis", "MSD algorithm", "ELD distance metric"]
# ["embroidery", "conductive thread", "liquid crystal textile displays", "thermal formgiving techniques", "thread modeling tool", "morphological design space"]
# ["piezoresistivity", "thermal bonding", "washing"]
# ["haptic cues", "textile interfaces", "haptic icons"]
# ["contrastive self-supervised learning", "latent space", "scalar", "roller", "visual representation"]
# ["minimal repeated pattern", "color dividing", "plate-making system", "IoT-based printing fabric industry", "neighbor similarity point location (NSPL)", "sub-pattern retrieval problem"]
# ```python
# ["embroidery machine", "stitch-level planning", "path planning algorithm"]
# ```
# ["tangible drape measurements", "scientific drape measurements", "postphenomenological approach"]
# ["shadow displays", "shape memory alloys (SMA)", "dynamic shadows", "ambient information display", "user study"]
# ["latent space", "contrastive self-supervised learning", "1D distance"]
# - method that they used to fabricate the smart fabric: fabric-silicone
# - tools used:  NA
# - materials used: fabric-silicone
# - what they did with the smart fabric: haptic feedback
# - if they conduct any user study: user study
# - special techniques used:  NA
# Error generating keywords for https://doi.org/10.1145/3594806.3594853: Expecting value: line 1 column 1 (char 0)
# ```python
# [
#     "Swept frequency capacitive sensing (SFCS)",
#     "fabric electrode",
#     "interactive fabric sensor",
#     "per-user training",
#     "real-time classification",
#     "contextual interactions"
# ]
# ```
# ["heat-activated adhesive materials", "smart textiles", "printed electronics", "handheld dispenser tool", "continuous functional tapes", "discrete patches", "custom-shaped I/O modules", "input", "output", "wiring", "computing"]
# ["e-textile", "embroidery machine", "conductive thread", "physical interface design", "user study"]
# ["woven", "common weaving machines", "conductive fiber", "pressure sensing", "anti-pressure-ulcer treatment", "wearable foot-pressure sensor", "walk and skill analyses"]
# Error generating keywords for https://doi.org/10.1145/3537797.3537880: The `response.text` quick accessor only works for simple (single-`Part`) text responses. This response is not simple text.Use the `result.parts` accessor or the full `result.candidates[index].content.parts` lookup instead.
# ["tactile contrast", "minimal recognizable size", "concave and convex shapes", "shape indication", "tactile symbols", "user study"]
# ["intuitive gesture affordance", "emotional effects", "touch-only", "visual feedback", "audio feedback", "multisensory feedback", "gesture-based interaction", "user emotions"]
# ["capacitive sensing", "smart textile", "embroidery machine", "conductive thread", "sensing", "full-body capturing suit"]
# ```python
# ["destaining", "TiO2/Ag", "self-cleaning", "self-deStaining", "LEDs", "moisture sensors", "self-cleaning clothes", "phone cases", "accessories"]
# ```
# ["tactile body maps", "textured fabric circles", "felt-shaped body", "drawing body maps", "verbal-only body descriptions"]
# ["Interactive Carpet", "Autism Spectrum Disorder (ASD)", "social skills", "physical properties", "multi-sensory feedback"]
# ["self-powered", "TENG", "embroidery machine", "silicone-textile composite", "sensing", "discrete touch detection", "multi-contact detection", "contact localization", "gesture recognition", "user study"]
# ["textile sensor layout", "personalized scenarios", "smart garments", "scoliosis"]
# ["e-textiles", "crafting", "older adults", "Planner-Improviser Spectrum", "familiar materials", "aesthetic goals", "attainable electronics"]
# ```python
# ["artificial patina", "threadbareness", "conductive patches", "tangible animations", "distressed swatches", "sensory perspectives", "ambient interfaces"]
# ```
# ["sensing", "embroidery machine", "conductive thread"]
# ["ZnO nanorods", "fabric substrates", "gas sensing", "electrical resistance change", "acetone", "ethanol"]
# ["pneumatic actuators", "3d printed grid structure", "temporal expressions", "textile interfaces", "computational simulation tool", "spatial shape change", "user study"]
# ["capacitive proximity sensing", "electrode material", "electrode design", "e-textiles", "flexible Smart Environment applications"]
# Error generating keywords for https://doi.org/10.1145/3495018.3495145: The `response.text` quick accessor only works for simple (single-`Part`) text responses. This response is not simple text.Use the `result.parts` accessor or the full `result.candidates[index].content.parts` lookup instead.
# ["sensing", "capacitive", "resistive polymer cord", "stitched", "linear-strain bench test", "simulated swelling experiment"]
# ["heat-activated adhesive materials", "smart textiles", "printed electronics", "handheld dispenser tool", "continuous functional tapes", "discrete patches", "input", "output", "wiring", "computing", "user study"]
# 1. N/A
# 2. N/A
# 3. N/A
# 4. Color transfer, texture modulation
# 5. User study
# 6. N/A
# Error generating keywords for https://doi.org/10.1145/3054953: Extra data: line 1 column 2 (char 1)
# ["force sensing", "resistive yarn", "Force Sensitive Resistor (FSR)", "knitting", "resistive wales", "resistive insert", "haptic qualities"]
# ```python
# ["ball grid array", "conductive textile pads", "stretchable pocket"]
# ```
# ["multiplicity", "extended life cycles", "conformal", "seamless", "sustainable"]
# ["theremin", "conductive textile antennas", "deep learning", "user study"]
# ["inductive sensing", "capacitive sensing", "resistive sensing", "NFC", "object recognition", "gesture recognition", "NFC tag detection", "user study"]
# ["touch-sensitive", "passive capacitive sensing", "graphene-based textile"]
# [“e-textile”, “sound boards”, “traditional crafting”, “touch based forms of interaction”]
# Error generating keywords for https://doi.org/10.1145/3419249.3421233: Expecting value: line 1 column 2 (char 1)
# ["multiplicity", "extended life cycles", "conformal", "seamless", "sustainable"]
# ["theremin", "conductive textile antennas", "deep learning", "user study"]
# ["Pecuest, "fabrication of, for example, if it is not applicable, and provide, and you can use a for the, in some, in, out of the box on the, and, sensor, actuator, and, or not
# Error generating keywords for https://doi.org/10.1145/3527927.3531451: Expecting ',' delimiter: line 1 column 13 (char 12)
# ["stitch samplers", "e-textile", "pattern-making", "DIY", "maker cultures", "soft form factors", "distance learning", "hybrid craft techniques"]
# ```python
# ["low volume production", "e-textiles", "prototype-to-production", "production standards", "apparel manufacturing", "hardware manufacturing", "manufacturing costs", "market expectations", "production-capable e-textile solutions", "tools", "materials", "community support"]
# ```
# 1. Fabrication method: N/A
# 2. Tools used: Embroidery machine
# 3. Materials used: Conductive thread
# 4. Applications: Sensing, real-time continuous control, discrete actions, mode switching
# 5. User study: User study
# 6. Special techniques used: N/A
# Error generating keywords for https://doi.org/10.1145/3313831.3376236: Extra data: line 1 column 2 (char 1)
# ["statistical distribution", "swallow frequency", "nutrition events", "cognitive disease monitoring", "elderly care"]
# ["E-Textile", "Wearable Communication Board", "horse therapy"]
# ["shape-changing", "physical buttons", "multi-sensory", "haptic", "visual", "interactive", "feedforward", "feedback", "expressivity", "tactile sensations"]
# ["e-textile", "body temperature", "pulse rate", "warning mechanism"]
# - fabrication method: NA
# - tools: NA
# - materials: NA
# - applications: gesture recognition, MIDI control
# - user study: NA
# - special techniques: NA
# Error generating keywords for https://doi.org/10.1145/3430524.3442451: Expecting value: line 1 column 1 (char 0)
# ["fabric touch experiences", "sensory associations", "emotional responses", "FabTouch", "design of fabric experiences"]
# ["graphene e-textile strain sensors", "embroidery", "sensing", "inertia measurement unit", "user study"]
# ["pressure sensors", "pressure distribution", "neonatal monitoring", "Neonatal Intensive Care Units (NICU)", "comfort assessment"]
# ```python
# ["fabric type pressure sensors", "smart pad", "body pressure distribution"]
# ```
# ["pressure sensing", "bio-impedance sensing", "embroidery"]
# ["wallpaper", "IoT", "touch gestures", "user study"]
# ["multi-sensory feedback", "fabric-based interactive surface", "user-centered design methodology", "deformable surfaces"]
# ["knitting machine", "resistive yarn", "pressure sensing", "analog rocker", "four-way directional buttons", "mode-switching"]
# ["all-textile", "embroidered", "sensing", "spindles", "K-complexes", "polysomnography (PSG)"]
# ["interactive surface", "BendableSound", "fabric-based interactive surface", "piano sounds", "early education classrooms", "cognitive", "social", "physical development", "deformable surfaces"]
# ["stroking", "squeezing", "valence", "arousal", "wrist-worn haptic devices"]
# ["not applicable"]
# ["multi-touch", "multi-pressure", "non-planar surfaces", "stretchable", "flexible", "bendable", "three-dimensional surface geometries", "shape-changing surfaces", "internal air-pressure", "malleable inflatable objects"]
# 1. Fabrication method: Embroidery
# 2. Tools used: Embroidery machine
# 3. Materials used: Custom-made sensors and actuators
# 4. Applications: Inferring textile deformation, body shape reconstruction, muscle density measurement, fabrication of orthotics and prosthetics, movement sensing for human activity
# 5. User study: Not applicable
# 6. Special techniques used: Optimisation-based algorithm, loss function minimisation
# Error generating keywords for https://doi.org/10.1145/3460418.3479347: Extra data: line 1 column 2 (char 1)
# ["pressure-map sensors", "textile-type", "touching patterns", "emotional arousal", "emotional valence"]
# ["textile pressure sensors", "body-pressure distribution", "posture change skill", "pressure ulcer prevention", "nursing students", "user study"]
# ```python
# keywords = [
#     "actuated fibers",
#     "fluidic artificial muscles",
#     "soft, line-based material system",
#     "integrated soft sensors",
#     "perceivably strong forces",
#     "high speed of linear actuation",
#     "haptic devices",
#     "tangible interfaces",
#     "robotic crafting",
#     "fluidic I/O control system",
#     "omni-functional fluidic fibers",
#     "HCI toolbox of interactive morphing materials",
# ]
# ```
# Error generating keywords for https://doi.org/10.1145/3472749.3474802: Expecting value: line 1 column 1 (char 0)
# 1. NA
# 2. NA
# 3. NA
# 4. Identification of skin irritation, chemical substances, and fabric type
# 5. NA
# 6. Support vector machine, principal component analysis
# Error generating keywords for https://doi.org/10.1145/3507959.3507962: Extra data: line 1 column 2 (char 1)
# ```python
# ["plain weave", "twill weave", "satin weave", "square plain fabric", "twill variation fabric", "satin variation fabric", "tensile fracture", "burst performance", "thickness"]
# ```
# ["digital embroidery", "wireless connection", "tactile interactions", "fabric-based sensors", "user study"]
# ["eTextiles", "Arpilleras", "STEAM", "soft interactive interfaces", "cultural heritage", "educational program", "specially designed kit", "new audiences", "revitalize the traditional technique", "expression", "creativity"]
# ["repositioning", "stretchable", "flexible", "custom fitting", "dynamic functionality", "sensors", "actuators"]
# ["co-design", "occupational therapists", "acquired brain injuries", "soft switches", "Human-Computer Interaction"]
# ["layering", "transmissive liquid crystal film", "dot patterns", "printed pattern", "garments"]
# ["project-based learning", "team-based learning", "self-made Smart Textile objects", "primary school level", "curriculum modules", "project learning", "teacher training", "TACCLE3 coding project"]
# ["embroidery", "quilting", "vibrotactile feedback", "improvised action", "emotional responses"]
# ["pinching", "draping", "stretching", "squeezing", "flexibility", "shape-taking"]
# ["affective computing", "e-textiles", "smart materials", "sensor technologies", "textile mirror", "Nitinol wire", "textural structure", "emotional signals", "online surveys", "user study"]
# ["proportional control", "fabric's topological constraints", "tactile movements"]
# ["eyes-free", "multitouch", "capacitive sensing", "gesture interactions", "text recognition", "fabric attenuation"]
# - fabrication method: NA
# - tools: NA
# - materials: electromagnetic
# - application: haptic feedback
# - user study: yes
# - special techniques: NA
# Error generating keywords for https://doi.org/10.1145/1520340.1520542: Expecting value: line 1 column 1 (char 0)
# ,
# Error generating keywords for https://doi.org/10.1145/3202185.3210770: Expecting value: line 1 column 1 (char 0)
# ["grabbing", "fold", "two-dimensional", "textile sensor", "invisibly", "arbitrary position", "stroke gestures"]
# ["embroidery", "quilting", "fabrication technologies", "game design practices"]
# ["tangible patterns", "sensors", "cameras", "computation", "physical objects", "materials"]
# ["voluminous", "sculptural", "wearable", "sonic feedback", "electromagnetic fields", "performative space", "body-space-object interaction"]
# ["strain sensors", "shape reconstruction", "optimisation process", "muscle density measurements", "movement tracking", "orthoses", "prostheses"]
# ["shape-changing", "strings", "sewing", "curved shapes", "textiles"]
# ["electrostatic actuation", "transparent indium tin oxide electrodes", "high-voltage modulation", "vibro-tactile feedback", "shape-changing interface", "frequency modulation", "2.5D deformable displays"]
# ["programming", "digital fabrication", "heat transfer material", "textiles", "user study"]
# ["embroidery", "technical threads", "digital embroidery/laying machine", "sensing"]
# ["pressure sensing", "e-textile", "bellyband interface", "abdominal pressure", "corset", "pressure changes", "laugh detection"]
# ["pinch angle", "menu selection", "two-dimensional foldable textile controllers", "marking menus", "Grabrics", "textile sensor"]
# ["dynamic textile materials", "interactive behaviours", "dynamic textile patterns", "wearable items", "person-to-person communication", "proximity", "local weather conditions", "dynamic language of wearable expression", "aesthetics", "pattern", "computation", "everyday artifacts", "personal", "cultural meaning"]
# ```python
# ["textile pressure sensor", "machine learning", "posture classification"]
# ```
# ['wearable computing', 'at-risk children', 'design studio culture', 'art therapy', 'hands-on making', 'expressive ideas', 'interactive projects', 'mentoring strategy']
# Error generating keywords for https://doi.org/10.1145/1978942.1979380: Expecting value: line 1 column 2 (char 1)
# ["e-textiles", "project repository", "community gathering place"]
# ["thermochromic inks", "peltier semiconductor elements", "ubiquitous fabric display"]
# ["modular textile system", "ambient displays", "interactive material", "computational behavior", "fabric interfaces", "modular based systems", "speech interaction", "illumination", "object recognition"]
# ["sensing", "postural states", "pressure sensors", "chair covers", "trousers", "user study"]
# ["under-extrusion", "fused deposition modeling (FDM) printers", "tulle-like fabrics"]
# ["bending", "pressing", "conductive elastomers", "threads", "fabric", "finger-worn", "interaction tool", "natural feedback", "proprioception", "mobile interaction", "wearable devices"]
# ["debugging", "LilyPad Arduino", "peer collaboration"]
# ["ECG", "textile electrodes", "wearable monitoring", "signal quality", "silver based textile electrodes"]
# ["non-invasive", "self-applicable", "customizable", "dynamic", "user-driven", "sensing", "actuating", "haptic feedback", "user study"]
# ["e-textiles", "visible mending", "e-textile darning", "darning looms", "educational samples", "sustainable making practices"]
# ["dual-sided", "woven", "touch sensor", "capacitive sensing", "multi-layer textile weaving", "smart apparel", "home decoration", "toys"]
# ["actuating", "thermal shape changing fabric", "laminate thermal expansion"]
# - **Fabrication method:** NA
# - **Tools used:** NA
# - **Materials used:** NA
# - **Textile applications:** Sensing
# - **User study:** NA
# - **Special techniques:** NA
# Error generating keywords for https://doi.org/10.1145/2494091.2494157: Expecting value: line 1 column 1 (char 0)
# ["Internet of Things", "Bluetooth technology", "Tangible User Interface"]
# ```python
# ["embroidery machine", "TurtleStitch", "Processing Stitch", "crocheting", "quilting", "weaving", "tapestry", "embroidery machine file formats", "scheduling", "product testing", "collaborative crochet", "quilted projects", "team dynamics"]
# ```
# ["6 Degrees-of-Freedom control", "acoustically- transparent", "interactive mid-air experiences", "levitated anchors", "levitated structures", "real- time", "free-form interactive elements", "projection surfaces", "authoring tool", "optimum locations", "anchors", "trapping forces", "prop stability", "maximum size", "interactive storytelling", "games", "mid-air displays"]
# ["fabric-based controllers", "textile interfaces", "user study"]
# ["debugging", "physical computing", "multimeter", "voltage", "current flow"]
# - method that they used to fabricate textiles: NA
# - tools used: NA
# - materials used: NA
# - what they did with the textiles: sensing
# - if they conduct any workshop or user study: user study
# - special techniques used: NA
# Error generating keywords for https://doi.org/10.1145/3410531.3414305: Expecting value: line 1 column 1 (char 0)
# ["shape-changing fabric", "airflow control", "fabric deformation", "respiration patterns", "hand gestures", "computational model", "airflow pressure", "interactive art installation"]
# ["Machine Learning", "Electrical circuit", "User-friendly tool"]
# ["debugging", "Arduino", "Adafruit Circuit Playground Classic", "breakpoint", "Serial communication", "digital pins", "LEDs"]
# ```python
# [
#     "fabrication method: conductive painting and conductive thread embroidery",
#     "materials: conductive silicon, conductive thread",
#     "what they did with the smart fabric: multimodal input device for mobile interaction",
#     "applications: music player control, smart glass interaction"
# ]
# ```
# ["construction", "tangible materials", "computer programs"]
# [“shape-changing”, “textural”, “embroidery machine”]
# Error generating keywords for https://doi.org/10.1145/2757226.2757231: Expecting value: line 1 column 2 (char 1)
# ["sensing", "embroidery machine", "user study"]
# ["embroidery", "sewing", "textile construction kits", "Barbie Fashion Designer", "LilyPad Arduino", "computation", "ICT", "fashion", "craft", "learning", "play", "broadening participation in computing fields"]
# ["user study", "embroidery machine", "conductive thread"]
# ["proximity sensing", "Lumalive displays", "touch-sensitive", "interactive e-textile displays", "Universal Resource Indicator (URI)"]
# ["capacitive sensing", "deep regressor", "fashion-technology co-design", "textile capacitive sensors", "unsupervised class discovery", "wearable motion tracking", "wearable motion recognition"]
# ["PEDOT-PSS", "EMG", "masticatory muscles", "motion artifact reduction", "correlation coefficient"]
# ["resistive pressure sensing", "conductive and resistive yarn", "hand sewing", "machine sewing", "weaving", "interactive capabilities"]
# ["touch sensitive", "thermochromic inks", "peltier semi-conductor display", "impulse temperature", "tic-tac-toe gaming platform", "interactive drawing pad", "user study"]
# ["IoT", "wireless data processing", "wearables", "fashion"]
# ["textile pressure sensing matrices", "contact speed", "contact angles", "kick robot", "embroidered", "sensing"]
# ["fabric interference", "near infrared sensor noise", "software/hardware solutions", "strategic fabric selection", "soft-good construction"]
# ```python
# ["non-emissive", "dynamic patterns", "thermochromic paints"]
# ```
# ["fabric-based", "interactive surfaces", "BendableSound", "user-centered design", "interviewing", "observation", "design sessions", "caregivers"]
# 1. Fabrication method: embroidery, felting
# 2. Tools: embroidery machine
# 3. Materials: polymeric photonic fiber (POF)
# 4. Application: transforming interiors via color, luminesce, and surface design
# 5. User study: N/A
# 6. Special techniques: N/A
# Error generating keywords for https://doi.org/10.1145/2347504.2347542: Extra data: line 1 column 2 (char 1)
# ["conductive fabric sensors", "pressure sensing", "signal processing algorithms", "deep learning model", "linear regression", "user study"]
# ["magnetically attachable electronic modules", "circuit creation", "responsive, interactive behaviors", "user study"]
# ```python
# ["conductive thread", "conductive ink", "resistivity"]
# ```
# ["goldwork embroidery", "metal threads", "metalwork", "e-textiles", "English goldwork", "HCI", "goldwork practices", "e-textile hybrid crafts"]
# ["Shoogleit", "interactive video", "iOS mobile devices", "textile qualities"]

# %%
# write to firestore database
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import json

# initialize Firebase Admin SDK
# cred = credentials.Certificate('./serviceAccountKey.json')  # 替换为你的Firebase Admin SDK密钥文件路径
# firebase_admin.initialize_app(cred)

db = firestore.client()

# read the paper data from the JSON file
with open('./data/paper_data_final.json', 'r', encoding='utf-8') as file:
    papers_data = json.load(file)

# write the paper data to Firestore
for paper in papers_data:
    # create a new document in the "paper" collection
    doc_ref = db.collection('paper').document()  # automatically generate a unique ID
    doc_ref.set(paper)
    print(f"Document for {paper['title']} added.")

print("All papers have been added to Firestore.")
# Out:
# Document for E-textile capacitive electrodes: Fabric or thread: designing an E-textile cushion for sitting posture detection added.
# Document for Aural Fabric: an interactive textile sonic map added.
# Document for Textile++: low cost textile interface using the principle of resistive touch sensing added.
# Document for Social fabric fitness: the design and evaluation of wearable E-textile displays to support group running added.
# Document for Textile Manager: Design and Development of a Persuasive Game about Sustainable Textile Production added.
# Document for Active textile tailoring added.
# Document for Handcrafting textile mice added.
# Document for Scalable Fabric: flexible task management added.
# Document for 3D printing on fabric added.
# Document for Fabric(a): Co-crafting Textiles with Robots added.
# Document for Mosaic textile: wearable ambient display with non-emissive color-changing modules added.
# Document for Designing an interface between the textile and electronics using e-textile composites added.
# Document for Textile displays: using textiles to investigate computational technology as design material added.
# Document for Hydrogel-Textile Composites: Actuators for Shape-Changing Interfaces added.
# Document for Soft printing with fabric added.
# Document for Multi-layer e-textile circuits added.
# Document for Making textile sensors from scratch added.
# Document for Crafting Tools for Textile Electronic Making added.
# Document for PocketView: Through-Fabric Information Displays added.
# Document for Computational design of fabric formwork added.
# Document for Alternative Presents for Dynamic Fabric added.
# Document for Disappearing textile interface with inherent feedforwards added.
# Document for Textile Game Controllers: Exploring Affordances of E-Textile Techniques as Applied to Alternative Game Controllers added.
# Document for From fiber to fabric: interactive clothing for virtual humans added.
# Document for 3D Printed Fabric: Techniques for Design and 3D Weaving Programmable Textiles added.
# Document for Fabric Defects Detection based on SSD added.
# Document for Smart Textile Using 3D Printed Conductive Sequins added.
# Document for Simulation of printed-on-fabric assemblies added.
# Document for Surface-mount manufacturing for e-textile circuits added.
# Document for Everyday creativity in novice e-textile designs added.
# Document for Energy-Aware Routing for E-Textile Applications added.
# Document for 2013 e-textile swatchbook exchange: the importance of sharing physical work added.
# Document for Modular E-Textile Platform for Real-Time Sensing added.
# Document for Intra-Acting Body and Textile Expressions Becoming with Digital Movement Translation: Exploring relational expressions of the body and textiles using a human-robot-textile installation added.
# Document for Intra-Acting Body and Textile Expressions Becoming with Digital Movement Translation: Exploring relational expressions of the body and textiles using a human-robot-textile installation added.
# Document for Ultra personalization and textile thinking in interaction design added.
# Document for KnitDema: Robotic Textile as Personalized Edema Mobilization Device added.
# Document for Weaving electronic circuit into two-layer fabric added.
# Document for SenSequins: Smart Textile Using 3D Printed Conductive Sequins added.
# Document for A telepresence system using a flexible textile display added.
# Document for Data Storage and Interaction using Magnetized Fabric added.
# Document for Tangible E-Textile Interactive Interface for Digital Patternmaking added.
# Document for Integrating Textile Materials with Electronic Making: Creating New Tools and Practices added.
# Document for Biceps fatigue estimation with an E-textile headband added.
# Document for E-textile Production of Wearable Ambient Notification Devices added.
# Document for The ThreadBoard: Designing an E-Textile Rapid Prototyping Board added.
# Document for Detecting bends and fabric folds using stitched sensors added.
# Document for Washability of e-textile stretch sensors and sensor insulation added.
# Document for Handcrafting textile interfaces from a kit-of-no-parts added.
# Document for A Textile Antenna for Wearable Applications Using RFID Technology added.
# Document for Weaving Textile-form Interfaces: A Material-Driven Design Journey added.
# Document for Textile Game Controller: Smart knee pads for Therapeutic Exercising  added.
# Document for A smart textile sleeve for rehabilitation of knee injuries added.
# Document for Shape Changing Fabric Samples for Interactive Fashion Design added.
# Document for Exploring Affordances of Surface Gestures on Textile User Interfaces added.
# Document for Demonstrating a Modular Construction Toolkit for Interactive Textile Applications added.
# Document for Stymphalian Birds - Exploring the Aesthetics of A Hybrid Textile added.
# Document for LIGHT TISSUE: Development of cellulose-based optical textile sensors added.
# Document for A Study Relating Computational Textile Textural Expression to Emotion added.
# Document for Hands-free gesture control with a capacitive textile neckband added.
# Document for The Sound of Textile: An Interactive Tactile-Sonic Installation added.
# Document for Electronic-textile system for the evaluation of wearable technology added.
# Document for Human joint angle estimation with an e-textile sensor added.
# Document for Toward the development of customizable textile-integrated thermal actuators added.
# Document for Initial Investigations into Characterizing DIY E-Textile Stretch Sensors added.
# Document for A Layered Fabric 3D Printer for Soft Interactive Objects added.
# Document for Soft Speakers: Digital Embroidering of DIY Customizable Fabric Actuators added.
# Document for TexonMask: Facial Expression Recognition Using Textile Electrodes on Commodity Facemasks added.
# Document for Embroidered Resistive Pressure Sensors: A Novel Approach for Textile Interfaces added.
# Document for SensorSnaps: Integrating Wireless Sensor Nodes into Fabric Snap Fasteners for Textile Interfaces added.
# Document for Fabric Electrodes for Physiological Sensing in a VR HMD added.
# Document for EmTex: Prototyping Textile-Based Interfaces through An Embroidered Construction Kit added.
# Document for Crafting Stories: Smart and Electronic Textile Craftsmanship for Interactive Books added.
# Document for Bi-metallic stitched e-textile sensors for sensing salinized liquids added.
# Document for Effects of the textile-sensor interface on stitched strain sensor performance added.
# Document for A temerature-based touch-sensor for non-emissive textile displays added.
# Document for StretchEBand: Enabling Fabric-based Interactions through Rapid Fabrication of Textile Stretch Sensors added.
# Document for Challenges and opportunities of textile based smart sanitary napkin design added.
# Document for Fabric-based ECG Electorde Jet Printing Formation and Performance Test added.
# Document for Toward Accurate Sensing with Knitted Fabric: Applications and Technical Considerations added.
# Document for Embr: A Creative Framework for Hand Embroidered Liquid Crystal Textile Displays added.
# Document for Effect of bonding and washing on electronic textile stretch sensor properties added.
# Document for What’s That Shape? Investigating Eyes-Free Recognition of Textile Icons added.
# Document for Telextiles: End-to-end Remote Transmission of Fabric Tactile Sensation added.
# Document for Automatic Detection of Minimal Repeated Pattern in Printing Fabric Images added.
# Document for Precision control of tensile properties in fabric for computational fabrication added.
# Document for Fold, Stand and Drape: Unweaving Physical vs Digital Textile Design Considerations added.
# Document for Exploring a Textile-based Shadow Lamp Display Incorporating Shape Memory Alloys added.
# Document for Telextiles: End-to-end Remote Transmission of Fabric Tactile Sensation added.
# Document for Fabric-Silicone Composite Haptic Muscles for Sensitive Wearable Force Feedback added.
# Document for eGlove: Designing Interactive Fabric Sensor for Enhancing Contact-Based Interactions added.
# Document for Rapid Iron-On User Interfaces: Hands-on Fabrication of Interactive Textile Prototypes added.
# Document for Integrating Interactive Technology Concepts With Material Expertise in Textile Design Disciplines added.
# Document for E-textile pressure sensor based on conductive fiber and its structure added.
# Document for Justice-oriented Participatory Electronic Textile Making: Fostering shared spaces of knowledge dialogues through the process of making, un-making, and re-making justice-oriented participatory praxis added.
# Document for Design Investigation of Embroidered Interactive Elements on Non-Wearable Textile Interfaces added.
# Document for GesFabri: Exploring Affordances and Experience of Textile Interfaces for Gesture-based Interaction added.
# Document for MoCa'Collection: Normalizing Dynamic Textile Geometry with Capacitive Sensing in Design Centric Wearables added.
# Document for Self-deStaining Textiles: Designing Interactive Systems with Fabric, Stains and Light added.
# Document for Tactile Narratives: Augmenting Body Maps through Textured Fabric in Soma Design added.
# Document for The Interactive Carpet - Smart Textile Interface for Children on Autism Spectrum Disorder added.
# Document for Skinergy: Machine-Embroidered Silicone-Textile Composites as On-Skin Self-Powered Input Sensors added.
# Document for LayTex: A Design Tool for Generating Customized Textile Sensor Layouts in Wearable Computing added.
# Document for Speaking from Experience: Co-designing E-textile Projects with Older Adult Fiber Crafters added.
# Document for Pull It Together: Textile Patina as an Interface for Externalizing Invisible Tension added.
# Document for Fabric Pressure Sensors for Fine-Grained Interaction Detection in Plush Toys added.
# Document for Nanostructured gas sensors integrated into fabric for wearable breath monitoring system added.
# Document for TEX(alive): A TOOLKIT TO EXPLORE TEMPORAL EXPRESSIONS IN SHAPE-CHANGING TEXTILE INTERFACES added.
# Document for Performance Comparison of E-Textile Electrode Properties in a Capacitive Proximity Sensing Setting added.
# Document for Research on Innovative Design of Smart Textile Fabrics Based on Environmental Response Characteristics added.
# Document for A comparative feasibility analysis for sensing swelling with textile-based soft strain sensors added.
# Document for Demonstrating Rapid Iron-On User Interfaces: Hands-on Fabrication of Interactive Textile Prototypes added.
# Document for Fabric Appearance Control System for Example-Based Interactive Texture and Color Design added.
# Document for Knitted RESi: A Highly Flexible, Force-Sensitive Knitted Textile Based on Resistive Yarns added.
# Document for A ball-grid-array-like electronics-to-textile pocket connector for wearable electronics added.
# Document for Conformal, Seamless, Sustainable: Multimorphic Textile-forms as a Material-Driven Design Approach for HCI added.
# Document for MoCapaci: Posture and gesture detection in loose garments using textile cables as capacitive antennas added.
# Document for Project Tasca: Enabling Touch and Contextual Interactions with a Pocket-based Textile Sensor added.
# Document for Project Mihr: Enabling Gestural Interactions on a Keyboard using a Graphene-based Fabric added.
# Document for Tactile Stories: Interactive E-textile Wall-hangings created by blind and visually impaired makers added.
# Document for Conformal, Seamless, Sustainable: Multimorphic Textile-forms as a Material-Driven Design Approach for HCI added.
# Document for MoCapaci: Posture and gesture detection in loose garments using textile cables as capacitive antennas added.
# Document for Tapis Magique: Machine-knitted Electronic Textile Carpet for Interactive Choreomusical Performance and Immersive Environments added.
# Document for Learning with Stitch Samplers: Exploring Stitch Samplers as Contextual Instructions for E-textile Tutorials added.
# Document for Scaling E-Textile Production: Understanding the Challenges of Soft Wearable Production for Individual Creators added.
# Document for E-Textile Microinteractions: Augmenting Twist with Flick, Slide and Grasp Gestures for Soft Electronics added.
# Document for Activity recognition and nutrition monitoring in every day situations with a textile capacitive neckband added.
# Document for An electronic-textile wearable communication board for individuals with autism engaged in horse therapy added.
# Document for Seamlessly Embedding Buttons into the Leather Fabric of a Car Interior, an Exploration added.
# Document for Hardware Development for Jogger-Specific Vital Signs Monitoring with Alarm Mechanism using E-Textile Technology added.
# Document for An Interactive Garment for Orchestra Conducting: IoT-enabled Textile & Machine Learning to Direct Musical Performance added.
# Document for FabTouch: A Tool to Enable Communication and Design of Tactile and Affective Fabric Experiences added.
# Document for E-textile Sleeve with Graphene Strain Sensors for Arm Gesture Classification of Mid-Air Interactions added.
# Document for Design of a smart textile mat to study pressure distribution on multiple foam material configurations added.
# Document for Recognition Algorithm for Sleep Postures using a Smart Fabric Pad with Multiple Pressure Sensors added.
# Document for A generic sensor fabric for multi-modal swallowing sensing in regular upper-body shirts added.
# Document for Connecting Textiles: Exploring Textile Interior Surfaces for Power Supply, Communication and User Interaction in the IoT added.
# Document for Designing a Musical Fabric-Based Surface to Encourage Children with Autism to Practice Motor Movements added.
# Document for spaceR: Knitting Ready-Made, Tactile, and Highly Responsive Spacer-Fabric Force Sensors for Continuous Input added.
# Document for PhyMask: Robust Sensing of Brain Activity and Physiological Signals During Sleep with an All-textile Eye Mask added.
# Document for Collective use of a fabric-based interactive surface to support early development in toddler classrooms added.
# Document for Emoband: Investigating the Affective Perception towards On-wrist Stroking and Squeezing Feedback mediated by Different Textile Materials added.
# Document for A Wearable Meter That Actively Monitors the Continuity of E-Textile Circuits as They Are Sewn added.
# Document for A Stretch-Flexible Textile Multitouch Sensor for User Input on Inflatable Membrane Structures & Non-Planar Surfaces added.
# Document for Inferring Complex Textile Shape from an Integrated Carbon Black-infused Ecoflex-based Bend and Stretch Sensor Array added.
# Document for Analyses of Textile Pressure-map Sensor Data of a Stuffed Toy for Understanding Human Emotional Physical Contact added.
# Document for Textile Sensor-based Visualization to Enhance Skills to Understand the Body-Pressure Distribution for Pressure Ulcer Prevention added.
# Document for OmniFiber: Integrated Fluidic Fiber Actuators for Weaving Movement based Interactions into the ‘Fabric of Everyday Life’ added.
# Document for Research on the Smart Fabric Interwoven with Polylactic Acid Fiber and Ramie Based on Mechanical Properties added.
# Document for FabriCar: Enriching the User Experience of In-Car Media Interactions with Ubiquitous Vehicle Interiors using E-textile Sensors added.
# Document for Arpilleras Parlantes: Designing Educational Material for the Creation of Interactive Textile Art Based on a Traditional Chilean Craft. added.
# Document for Plug-and-Play Wearables: A Repositionable E-Textile Garment System to Support Custom Fit for Lower-Limb Rehabilitation Applications added.
# Document for Adaptive Soft Switches: Co-Designing Fabric Adaptive Switches with Occupational Therapists for Children and Adolescents with Acquired Brain Injury added.
# Document for Expansion of Textile Expression Utilizing Op Art Methods and Transmissive Liquid Crystal Film, and Progress toward Its Use in Garments added.
# Document for Smart textile objects and conductible ink as a context for arts based teaching and learning of computational thinking at primary school added.
# Document for Touch Connection: A Vibrotactile, Textile Prototype added.
# Document for Cloth displays: interacting with drapable textile screens added.
# Document for Actuating mood: design of the textile mirror added.
# Document for Zstretch: a stretchy fabric music controller added.
# Document for PocketTouch: through-fabric capacitive touch input added.
# Document for BubbleWrap: a textile-based electromagnetic haptic display added.
# Document for Patchwork: an expressive e-textile construction kit added.
# Document for Grabrics: A Foldable Two-Dimensional Textile Input Controller added.
# Document for Threadsteading: Playful Interaction for Textile Fabrication Devices added.
# Document for Pattern Stations: Extending Textile Materials through Tangible Interaction added.
# Document for Disobedient Antennas: Breaking the Rules of Textile Antenna Design added.
# Document for ShapeSense3D: textile-sensing and reconstruction of body geometries added.
# Document for Filum: A Sewing Technique to Alter Textile Shapes added.
# Document for TableHop: An Actuated Fabric Display Using Transparent Electrodes added.
# Document for Diversity in Digital Fabrication: Programming Personally Meaningful Textile Imprints added.
# Document for Baby Tango: Electronic Textile Toys for Full-Body Interaction added.
# Document for Laugh Log: E-textile Bellyband Interface for Laugh Logging added.
# Document for Grabbing at an angle: menu selection for fabric interfaces added.
# Document for Reach: dynamic textile patterns for communication and social expression added.
# Document for Smart Arse: Posture Classification with Textile Sensors in Trousers added.
# Document for Breaking boundaries: strategies for mentoring through textile computing workshops added.
# Document for LilyPond: an online community for sharing e-textile projects added.
# Document for AmbiKraf: a ubiquitous non-emissive color changing fabric display added.
# Document for bYOB [Build Your Own Bag]: a computationally-enhanced modular textile system added.
# Document for Strike A Pose: Capturing Non-Verbal Behaviour with Textile Sensors added.
# Document for DefeXtiles: 3D Printing Quasi-Woven Fabric via Under-Extrusion added.
# Document for Plex: finger-worn textile sensor for mobile interaction during activities added.
# Document for Deconstruction Kits for Learning: Students' Collaborative Debugging of Electronic Textile Designs added.
# Document for Sensor validation for wearable monitoring system in ambulatory monitoring: application to textile electrodes added.
# Document for proCover: Sensory Augmentation of Prosthetic Limbs Using Smart Textile Covers added.
# Document for The E-darning Sampler: Exploring E-textile Repair with Darning Looms added.
# Document for ZebraSense: A Double-sided Textile Touch Sensor for Smart Clothing added.
# Document for ShapeTex: Implementing Shape-Changing Structures in Fabric for Wearable Actuation added.
# Document for SpiroVest: an e-textile-based wearable spirometer with posture change adaptability added.
# Document for Soft tangible user interfaces: coupling the digital information to the textile materials added.
# Document for Code Crafters Curriculum: A Textile Crafts Approach To Computer Science (Abstract Only) added.
# Document for LeviProps: Animating Levitated Optimized Fabric Structures using Holographic Acoustic Tweezers added.
# Document for Interactive FUrniTURE: Evaluation of Smart Interactive Textile Interfaces for Home Environments added.
# Document for A "Low-Floor" Multimeter: Supporting E-textile Debugging by Revealing Voltage and Continuity added.
# Document for Snacap: snacking behavior monitoring with smart fabric mechanomyography on the temporalis added.
# Document for reSpire: Self-awareness and Interpersonal Connectedness through Shape-changing Fabric Display added.
# Document for Workshop on Wearables and Machine Learning: Applications of Artificial Intelligence, Approaches on Textile Technology added.
# Document for Pin Status: An Arduino Debugging Library for High School E-textile Courses added.
# Document for TIMMi: Finger-worn Textile Input Device with Multimodal Sensing in Mobile Interaction added.
# Document for TechSportiv: using a smart textile toolkit to approach young people's physical education added.
# Document for The Textility of Emotion: A Study Relating Computational Textile Textural Expression to Emotion added.
# Document for One leg at a time: towards optimised design engineering of textile sensors in trousers added.
# Document for Fröbel's forgotten gift: textile construction kits as pathways into play, design and computation added.
# Document for SnapToTrace: a new e-textile interface and component kit for learning computation added.
# Document for TagURit: a proximity-based game of tag using lumalive e-textile displays added.
# Document for MoCaPose: Motion Capturing with Textile-integrated Capacitive Sensors in Loose-fitting Smart Garments added.
# Document for hitoeCap: wearable EMG sensor for monitoring masticatory muscles with PEDOT-PSS textile electrodes added.
# Document for RESi: A Highly Flexible, Pressure-Sensitive, Imperceptible Textile Interface Based on Resistive Yarns added.
# Document for TempTouch: a novel touch sensor using temperature controllers for surface based textile displays added.
# Document for Connecting Couture: Engaging With the Crafted Textile Interface in an Internet of Things Ecology added.
# Document for Smart soccer shoe: monitoring foot-ball interaction with shoe integrated textile pressure sensor matrix added.
# Document for Throwing buddy: solving sensor challenges through soft-good construction, design, and fabric selection added.
# Document for Howel: A Soft Wearable with Dynamic Textile Patterns as an Ambient Display for Cardio Training added.
# Document for BendableSound: a Fabric-based Interactive Surface to Promote Free Play in Children with Autism added.
# Document for Interactive interiors: preliminary study of integrating textile embellishment techniques and polymeric photonic fibers for interior textiles added.
# Document for SmarCyPad: A Smart Seat Pad for Cycling Fitness Tracking Leveraging Low-cost Conductive Fabric Sensors added.
# Document for MakerShoe: towards a wearable e-textile construction kit to support creativity, playful making, and self-expression added.
# Document for Can i wash it?: the effect of washing conductive materials usedin making textile based wearable electronic interfaces. added.
# Document for Goldwork Embroidery: Interviews with Practitioners on Working with Metal Threads and Opportunities for E-textile Hybrid Crafts added.
# Document for Interactivity to enhance perception: does increased interactivity in mobile visual presentation tools facilitate more accurate rating of textile properties? added.
# All papers have been added to Firestore.

# %%
import json

# Read the JSON file
file_path = './data/paper_data_final.json'
with open(file_path, 'r') as file:
    papers = json.load(file)

# Generate the output in a TXT file
output_file_path = './data/papers_summary.txt'
with open(output_file_path, 'w') as output_file:
    for i, paper in enumerate(papers, start=1):
        title = paper.get('title', 'N/A')
        abstract_full = paper.get('abstract_full', 'N/A')
        doi = paper.get('doi', 'N/A')
        
        output_file.write(f'Title of paper {i}: {title}\n\n')
        output_file.write(f'Abstract of paper {i}: {abstract_full}\n\n')
        output_file.write(f'DOI of paper {i}: {doi}\n\n\n\n')

output_file_path
# Out:
# './data/papers_summary.txt'

# %%
# write to firestore database
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import json

# initialize Firebase Admin SDK
cred = credentials.Certificate('./serviceAccountKey.json')  # 替换为你的Firebase Admin SDK密钥文件路径
firebase_admin.initialize_app(cred)

db = firestore.client()

# %%
# change year to integer
# Reference to the collection
papers_ref = db.collection('paper')

# Fetch all documents
docs = papers_ref.stream()

for doc in docs:
    doc_dict = doc.to_dict()
    year_str = doc_dict.get('year')
    if year_str and year_str.isdigit():
        # Convert year to integer and update document
        papers_ref.document(doc.id).update({'year': int(year_str)})

print('Year fields updated successfully.')
# Out:
# Year fields updated successfully.

# %%
from firebase_admin import firestore

# Assuming Firebase Admin SDK is already initialized

db = firestore.client()

# Reference to the 'paper' collection
papers_ref = db.collection('paper')

# Fetch all documents
docs = papers_ref.stream()

for doc in docs:
    # Add document ID to its fields
    papers_ref.document(doc.id).update({'docId': doc.id})

print('Document IDs added successfully.')
# Out:
# Document IDs added successfully.

# %%
# Reference to the collection
papers_collection = db.collection('paper')

# Query for the document
query = papers_collection.where('title', '==', 'MoCapaci: Posture and gesture detection in loose garments using textile cables as capacitive antennas')
documents = query.stream()

for document in documents:
    print(f'Document ID: {document.id}')
# Out:
# Document ID: fNSVpbfiDuak84OCMCGf
# Document ID: qpFbXij7i6TVeKue2byT
